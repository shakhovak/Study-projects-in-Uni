# %% [markdown]
# # Задание Question answering. Практическое задание (PJ)
# Для закрепления материала модуля предлагаем вам решить задачу QA для датасета SberQuad, используя любые доступные вам средства.
#
# Для достижения наилучшего результата уделите внимание подбору гиперапарметров как в плане архитектуры, так и в плане обучения модели.
#
# <hr>
#
# **Критерии оценивания проекта:**
#
# - общее качество кода и следование PEP-8;
# - использование рекуррентных сетей;
# - использованы варианты архитектур, близкие к state of the art для данной задачи;
# - произведен подбор гиперпараметров;
# - использованы техники изменения learning rate (lr scheduler);
# - использована адекватная задаче функция потерь;
# - использованы техники регуляризации;
# - корректно проведена валидация модели;
# - использованы техники ensemble;
# - использованы дополнительные данные;
# - итоговое значение метрики качества > 0.75 (f1).
#
# <hr>

# %% [markdown]
# # План решения
#
# Задача fine-tune трансофрмерных моделей на датасете SQUAD считается классической в NLP, поэтому решать ее буду на основе tutorial c hugging face https://huggingface.co/learn/nlp-course/chapter7/7?fw=pt
#
# Обучение проходит достаточно долго, поэтому подбирать гиперпарметры я не буду, поработаю со теми  значениями, которые чаще всего рекомендуют.
#
# В качестве моделей буду использовать:
# - DeepPavlov/rubert-base-cased
#
#
#
# ## Импорт и обработка данных
# Импортируем датасет и посмотрим на длину контекстов в обучающем датасете.

# %%
import pandas as pd
import numpy as np

# %%
from datasets import load_dataset
raw_datasets = load_dataset("sberquad")
# Out:
# Found cached dataset sberquad (C:/Users/Kate/.cache/huggingface/datasets/sberquad/sberquad/1.0.0/3e53185d0662a022bd749ec2b67b20499070efcbc1475428b0dad76c2cf8b06b)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
raw_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 45328
#     })
#     validation: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 5036
#     })
#     test: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 23936
#     })
# })

# %%
print("Context: ", raw_datasets["train"][0]["context"])
print("Question: ", raw_datasets["train"][0]["question"])
print("Answer: ", raw_datasets["train"][0]["answers"])
# Out:
# Context:  В протерозойских отложениях органические остатки встречаются намного чаще, чем в архейских. Они представлены известковыми выделениями сине-зелёных водорослей, ходами червей, остатками кишечнополостных. Кроме известковых водорослей, к числу древнейших растительных остатков относятся скопления графито-углистого вещества, образовавшегося в результате разложения Corycium enigmaticum. В кремнистых сланцах железорудной формации Канады найдены нитевидные водоросли, грибные нити и формы, близкие современным кокколитофоридам. В железистых кварцитах Северной Америки и Сибири обнаружены железистые продукты жизнедеятельности бактерий.
# Question:  чем представлены органические остатки?
# Answer:  {'text': ['известковыми выделениями сине-зелёных водорослей'], 'answer_start': [109]}

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("DeepPavlov/rubert-base-cased")

# %%
import matplotlib.pyplot as plt
plt.hist(list(map(len, raw_datasets['train']['context'])), bins = 100);

# %% [markdown]
# Как оказалось, контексты довольно длинные и не войдут в стандартную длину токенов модели, поэтому воспользуемся предложенной авторами tutorial функцией, для разбивки текстов для длины 384 с окном 128. При этом в каждом части контекста будет определяться начальный и конечный токен ответа на вопрос (если он в нем есть).
#
# Для валидационной выборки воспользуемся похожей функцией, но без расчета позиций начального и конечного токена ответа на вопрос.

# %%
max_length = 384
stride = 128


def preprocess_training_examples(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=max_length,
        truncation="only_second",
        stride=stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    offset_mapping = inputs.pop("offset_mapping")
    sample_map = inputs.pop("overflow_to_sample_mapping")
    answers = examples["answers"]
    start_positions = []
    end_positions = []

    for i, offset in enumerate(offset_mapping):
        sample_idx = sample_map[i]
        answer = answers[sample_idx]
        start_char = answer["answer_start"][0]
        end_char = answer["answer_start"][0] + len(answer["text"][0])
        sequence_ids = inputs.sequence_ids(i)

        # Find the start and end of the context
        idx = 0
        while sequence_ids[idx] != 1:
            idx += 1
        context_start = idx
        while sequence_ids[idx] == 1:
            idx += 1
        context_end = idx - 1

        # If the answer is not fully inside the context, label is (0, 0)
        if offset[context_start][0] > start_char or offset[context_end][1] < end_char:
            start_positions.append(0)
            end_positions.append(0)
        else:
            # Otherwise it's the start and end token positions
            idx = context_start
            while idx <= context_end and offset[idx][0] <= start_char:
                idx += 1
            start_positions.append(idx - 1)

            idx = context_end
            while idx >= context_start and offset[idx][1] >= end_char:
                idx -= 1
            end_positions.append(idx + 1)

    inputs["start_positions"] = start_positions
    inputs["end_positions"] = end_positions
    return inputs

# %%
def preprocess_validation_examples(examples):
    questions = [q.strip() for q in examples["question"]]
    inputs = tokenizer(
        questions,
        examples["context"],
        max_length=max_length,
        truncation="only_second",
        stride=stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
    )

    sample_map = inputs.pop("overflow_to_sample_mapping")
    example_ids = []

    for i in range(len(inputs["input_ids"])):
        sample_idx = sample_map[i]
        example_ids.append(examples["id"][sample_idx])

        sequence_ids = inputs.sequence_ids(i)
        offset = inputs["offset_mapping"][i]
        inputs["offset_mapping"][i] = [
            o if sequence_ids[k] == 1 else None for k, o in enumerate(offset)
        ]

    inputs["example_id"] = example_ids
    return inputs

# %%
#sample_train = raw_datasets['train'].select(range(1000))
#sample_eval = raw_datasets['validation'].select(range(10))

# %%
train = raw_datasets['train'].map(
    preprocess_training_examples,
    batched=True,
    remove_columns=raw_datasets['train'].column_names,
)

val = raw_datasets['validation'].map(
    preprocess_validation_examples,
    batched=True,
    remove_columns=raw_datasets['validation'].column_names,
)

test = raw_datasets['test'].map(
    preprocess_validation_examples,
    batched=True,
    remove_columns=raw_datasets['test'].column_names,
)
# Out:
# Loading cached processed dataset at C:\Users\Kate\.cache\huggingface\datasets\sberquad\sberquad\1.0.0\3e53185d0662a022bd749ec2b67b20499070efcbc1475428b0dad76c2cf8b06b\cache-c7a9015d4f13853d.arrow
# Loading cached processed dataset at C:\Users\Kate\.cache\huggingface\datasets\sberquad\sberquad\1.0.0\3e53185d0662a022bd749ec2b67b20499070efcbc1475428b0dad76c2cf8b06b\cache-167c43688f4b023e.arrow
# Loading cached processed dataset at C:\Users\Kate\.cache\huggingface\datasets\sberquad\sberquad\1.0.0\3e53185d0662a022bd749ec2b67b20499070efcbc1475428b0dad76c2cf8b06b\cache-8c5cb914534751a1.arrow

# %% [markdown]
# ## Метрика качества
#
# Для squad_QA моделей существует специальная метрика squad https://huggingface.co/spaces/evaluate-metric/squad
#
# **For info:**
# The metric takes two files or two lists of question-answers dictionaries as inputs : one with the predictions of the model and the other with the references to be compared to.
#
# This metric outputs a dictionary with two values: the average exact match score and the average F1 score.
#
# - **Exact match** - % of answers that are matched
# - **F1** - standard average F1 for all classes
#
# Дополнительно посмотрим с помощью pipeline, как обученная модель работает с текстами.

# %%
import evaluate
metric = evaluate.load("squad")

# %%
from tqdm.auto import tqdm


def compute_metrics(start_logits, end_logits, features, examples):
    
    example_to_features = collections.defaultdict(list)
    for idx, feature in enumerate(features):
        example_to_features[feature["example_id"]].append(idx)

    predicted_answers = []
    for example in tqdm(examples):
        example_id = example["id"]
        context = example["context"]
        answers = []

        # Loop through all features associated with that example
        for feature_index in example_to_features[example_id]:
            start_logit = start_logits[feature_index]
            end_logit = end_logits[feature_index]
            offsets = features[feature_index]["offset_mapping"]

            start_indexes = np.argsort(start_logit)[-1 : -n_best - 1 : -1].tolist()
            end_indexes = np.argsort(end_logit)[-1 : -n_best - 1 : -1].tolist()
            for start_index in start_indexes:
                for end_index in end_indexes:
                    # Skip answers that are not fully in the context
                    if offsets[start_index] is None or offsets[end_index] is None:
                        continue
                    # Skip answers with a length that is either < 0 or > max_answer_length
                    if (
                        end_index < start_index
                        or end_index - start_index + 1 > max_answer_length
                    ):
                        continue

                    answer = {
                        "text": context[offsets[start_index][0] : offsets[end_index][1]],
                        "logit_score": start_logit[start_index] + end_logit[end_index],
                    }
                    answers.append(answer)

        # Select the answer with the best score
        if len(answers) > 0:
            best_answer = max(answers, key=lambda x: x["logit_score"])
            predicted_answers.append(
                {"id": str(example_id), "prediction_text": best_answer["text"]}
            )
        else:
            predicted_answers.append({"id": str(example_id), "prediction_text": ""})

    theoretical_answers = [{"id": str(ex["id"]), "answers": {'text':ex["answers"]['text'],
                                                        'answer_start':ex["answers"]['answer_start']}, } for ex in examples]

    return metric.compute(predictions=predicted_answers, references=theoretical_answers)

# %% [markdown]
# ## Обучение
#
# Для обучения буду использовать DefaultDataCollator и Trainer API. В качестве параметров возьму рекомендуемые learning rate + weight decay. Также добавлю параметр fp16, который должен помочь считать быстрее, но может привести к нестабильности расчетов. Так как это учебный пример, то, думаю, можно им воспользоваться.

# %%
from transformers import DefaultDataCollator
data_collator = DefaultDataCollator()

# %%
from transformers import AutoModelForQuestionAnswering, TrainingArguments, Trainer
model = AutoModelForQuestionAnswering.from_pretrained('DeepPavlov/rubert-base-cased')
# Out:
# Some weights of the model checkpoint at DeepPavlov/rubert-base-cased were not used when initializing BertForQuestionAnswering: ['cls.predictions.decoder.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at DeepPavlov/rubert-base-cased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir="qa_model",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    weight_decay=0.001,
    evaluation_strategy="epoch",
    push_to_hub=False,
    save_strategy="no", 
    fp16=True
   
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train,
    eval_dataset=val,
    tokenizer=tokenizer,
    data_collator=data_collator,
    
)

trainer.train()
# Out:
# C:\Users\Kate\anaconda3\lib\site-packages\transformers\optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='5694' max='5694' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5694/5694 1:13:23, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.609200</td>
#       <td>No log</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.273100</td>
#       <td>No log</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=5694, training_loss=1.552716881256586, metrics={'train_runtime': 4405.8051, 'train_samples_per_second': 20.675, 'train_steps_per_second': 1.292, 'total_flos': 1.7850749233176576e+16, 'train_loss': 1.552716881256586, 'epoch': 2.0})

# %% [markdown]
# ## Оценка качества
#
# Для оценки качества авторы предлагают использовать n_best start logits and end logits и ограничить длину ответа параметром max_answer_length.

# %%
n_best=20
max_answer_length = 30

# %%
import collections
predictions, _, _ = trainer.predict(val)
start_logits, end_logits = predictions

compute_metrics(start_logits, end_logits, val, raw_datasets['validation'])
# Out:
#   0%|          | 0/5036 [00:00<?, ?it/s]
# {'exact_match': 61.9142176330421, 'f1': 81.95959386550899}

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering", model=model, tokenizer = tokenizer, device = 0)

# %%
import torch
device = torch.device ('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
print(raw_datasets['validation'][0])
context = raw_datasets['validation'][0]['context']
question = raw_datasets['validation'][0]['question']
question_answerer(question=question, context=context)
# Out:
# {'id': 60544, 'title': 'SberChallenge', 'context': 'Первые упоминания о строении человеческого тела встречаются в Древнем Египте. В XXVII веке до н. э. египетский врач Имхотеп описал некоторые органы и их функции, в частности головной мозг, деятельность сердца, распространение крови по сосудам. В древнекитайской книге Нейцзин (XI—VII вв. до н. э.) упоминаются сердце, печень, лёгкие и другие органы тела человека. В индийской книге Аюрведа ( Знание жизни , IX-III вв. до н. э.) содержится большой объём анатомических данных о мышцах, нервах, типах телосложения и темперамента, головном и спинном мозге.', 'question': 'Где встречаются первые упоминания о строении человеческого тела?', 'answers': {'text': ['в Древнем Египте'], 'answer_start': [60]}}
# {'score': 0.3006110191345215,
#  'start': 60,
#  'end': 76,
#  'answer': 'в Древнем Египте'}

# %%
print(raw_datasets['validation'][10])
context = raw_datasets['validation'][10]['context']
question = raw_datasets['validation'][10]['question']
question_answerer(question=question, context=context)
# Out:
# {'id': 55742, 'title': 'SberChallenge', 'context': 'Судебная власть организована в форме пирамиды, основой которой в гражданской юстиции является мировой суд (фр. Justice de paix, нид. Vrederechter) и в уголовной юстиции — полицейские суды (фр. Tribunal de Police, нид. Politierechtbank), имеющийся в каждом судебном кантоне (фр. Canton judiciaire, нид. Gerechtelijk kanton), а верхушкой — Кассационный суд (фр. Cour de cassation, нид. Hof van Cassatie). Бельгия поделена на судебные кантоны и судебные округа. Каждый судебный округ (фр. Arrondissement judiciaire, нид. Gerechtelijk arrondissement) имеет суд первой инстанции (фр. Tribunal de première instance, нид. rechtbank van eerste aanleg), состоящий из палаты по гражданским вопросам (фр. chambres civiles, нид. kamer voor burgerlijke zaken), палаты по уголовным вопросам (фр. chambres correctionnelles, нид. kamer voor strafzaken) и палаты по молодёжным вопросам (фр. chambres de la jeunesse, нид. kamer voor jeugdzaken), трудовые суды (фр. Tribunal du Travail, нид. Arbeidsrechtbank) и торговые суды (фр. Tribunal de Commerce, нид. Rechtbank van koophandel). Также существует пять апелляционных судов (фр. Cour d’appel, нид. Hof van beroep), состоящие из палаты по гражданским, торговым и экономическим вопросам (нид. kamer voor burgerlijke zaken, handels- en economische zaken), палаты по уголовным вопросам (нид. kamer voor strafzaken), палаты молодёжным вопросам (нид. kamer voor jeugdzaken), и трудовые палаты (фр. Cour du Travail, нид. Arbeidshof) — в Брюсселе, Льеже, Монсе, Генте и Антверпене, и в каждой провинции — суд присяжных (фр. Cour d’Assises, нид. Hof van assisen).', 'question': 'Как организована судебная власть ?', 'answers': {'text': ['в форме пирамиды'], 'answer_start': [29]}}
# {'score': 0.4312654435634613,
#  'start': 29,
#  'end': 45,
#  'answer': 'в форме пирамиды'}

# %% [markdown]
# В принципе хорошо получилось: F1 получилось выше 81 и тексты тоже неплохо выглядят.
#
#
# ## Тестирование модели в соревновании CodeLab
#
# Так как в тестовом датасете не проставлены правильные ответы, то протестируем модель на соревновании в CodeLab на этом же датасете https://codalab.lisn.upsaclay.fr/competitions/7335#learn_the_details. Для этого загрузим тестовый датасет с сайта и с помощью функции ниже заполним ответы.

# %%
def answer_quest(context, question):
    answer = question_answerer(question=question, context=context)['answer']
    start = question_answerer(question=question, context=context)['start']
    return {'text':answer, 'answer_start':start}

# %%
import json
with open('sbersquad_test_data_to_solve.json', 'r', encoding='utf-8') as f:
    loaded = json.load(f)

new = loaded

# %%
from tqdm import tqdm_notebook
for i in tqdm_notebook(new['paragraphs']):
     for j in i['qas']:
            context =  i['context']
            question = j['question']
            j['answers'] = [answer_quest(context, question)]
new
# Out:
# C:\Users\Kate\AppData\Local\Temp\ipykernel_7628\3612885349.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(new['paragraphs']):
#   0%|          | 0/4421 [00:00<?, ?it/s]
# {'title': 'sberQUAD test',
#  'paragraphs': [{'context': 'К 1960-м годам жилищное строительство распространилось на район восточнее Батарейной горы, ранее застроенный, преимущественно, малоэтажными домами, значительная часть которых была разрушена в ходе войны. Застройка шла по типовым проектам жилых и общественных зданий, город приобретал советский облик, свойственный большинству новых районов в городах СССР. Меняется структура транспорта: на смену закрытому в 1957 году трамваю приходит автобус, а паровозы с 1969 года вытесняются электропоездами. Прежде главный двигатель выборгской экономики — Сайменский канал — вновь начал работу только в 1968 году. К 1970 году численность населения Выборга достигла 65 тыс. человек, что всё ещё было ниже довоенного уровня.',
#    'qas': [{'id': '8ac1590e97dd2d541eba44eb3bcd0eb15e9b9227',
#      'answers': [{'text': 'советский', 'answer_start': 284}],
#      'question': 'Какой облик, свойственный большинству новых районов в городах СССР, приобретал город, когда застройка шла по типовым проектам жилых и общественных зданий?'},
#     {'id': '1deeaf4e32ca8c547e802eb8ce5b99f252d2645a',
#      'answers': [{'text': 'восточнее Батарейной горы', 'answer_start': 64}],
#      'question': 'На какой район, ранее застроенный, преимущественно, малоэтажными домами, значительная часть которых была разрушена в ходе войны, к 1960-м годам распространилось жилищное строительство?'},
#     {'id': 'f1f9b0b058e2dfdb2eebf165d3cb27bd250db684',
#      'answers': [{'text': 'К 1960-м годам', 'answer_start': 0}],
#      'question': 'К каким годам жилищное строительство распространилось на район восточнее Батарейной горы, ранее застроенный, преимущественно, малоэтажными домами, значительная часть которых была разрушена в ходе войны?'},
#     {'id': '1a6108412c10916226599c853668a2cb37351d31',
#      'answers': [{'text': 'К 1960-м годам', 'answer_start': 0}],
#      'question': 'К каким годам жилищное строительство распространилось на район восточнее Батарейной горы?'},
#     {'id': '59d328a25568dec9042cf2da603e576f383f6268',
#      'answers': [{'text': 'советский', 'answer_start': 284}],
#      'question': 'Какой облик приобретал город?'},
#     {'id': 'ce7158743b30ee81d4a96ea11492e58ea151c0a1',
#      'answers': [{'text': 'восточнее Батарейной горы', 'answer_start': 64}],
#      'question': 'На какой район распространилось жилищное строительство к 1960-м годам?'},
#     {'id': '3867c985e2d712aee76630ebce6edadd8e9ffa55',
#      'answers': [{'text': 'К 1970 году', 'answer_start': 602}],
#      'question': 'К какому году численность населения Выборга достигла 65 тыс. человек?'},
#     {'id': 'a6c32f5a67aa3871487d828e8c65a9cc000f4f8d',
#      'answers': [{'text': 'автобус', 'answer_start': 435}],
#      'question': 'Какой вид транспорта приходит на смену закрытому в 1957 году трамваю?'},
#     {'id': '7adbb4281fa541840b4bf53cd5ce951da13e1e20',
#      'answers': [{'text': 'по типовым проектам жилых и общественных зданий',
#        'answer_start': 218}],
#      'question': 'По каким проектам шла застройка?'}]},
#   {'context': 'В западных культурах понятие мужчина , как и женщина , традиционно определяется в первую очередь через биологические особенности. Как отмечают некоторые исследователи, это связано с особым значением, которое в этих культурах придаётся природе. Однако во многих контекстах понятие мужчина обозначает прежде всего социальную группу, гендерную роль или гендерную идентичность. Хотя господствующая в современном мире бинарная гендерная система подразумевает жёсткое соответствие приписанного человеку при рождении пола и гендерной роли, в действительности они не всегда совпадают.',
#    'qas': [{'id': 'f6c9fb66d4b9f4603429638ab84edc675cca375c',
#      'answers': [{'text': 'бинарная', 'answer_start': 413}],
#      'question': 'Какая гендерная система господствует в современном мире?'},
#     {'id': 'a464dbb9d2cf7b689801bb1849659435b5edd173',
#      'answers': [{'text': 'жёсткое соответствие приписанного человеку при рождении пола и гендерной роли',
#        'answer_start': 454}],
#      'question': 'Что подразумевает в современном мире бинарная гендерная система?'},
#     {'id': '3e357e4e69951610a0a4c937463e6cc08f96e804',
#      'answers': [{'text': 'жёсткое соответствие приписанного человеку при рождении пола и гендерной роли',
#        'answer_start': 454}],
#      'question': 'Что подразумевает господствующая в современном мире бинарная гендерная система?'},
#     {'id': '7a2a924a9cdcc619615e4f8a9c6aae40aab1034f',
#      'answers': [{'text': 'В западных', 'answer_start': 0}],
#      'question': 'В каких культурах понятие мужчина , как и женщина , традиционно определяется в первую очередь через биологические особенности?'},
#     {'id': 'ba392369009c92fd33be6739cd44ab926922cbc0',
#      'answers': [{'text': 'социальную группу, гендерную роль или гендерную идентичность',
#        'answer_start': 312}],
#      'question': 'Что во многих контекстах означает понятие мужчина?'},
#     {'id': '69dbb709282322b366eab4f9d4c6d9d216afb0bd',
#      'answers': [{'text': 'природе', 'answer_start': 235}],
#      'question': 'Чему в западных культурах придается особое значение?'},
#     {'id': 'eafbd5d671e218a64a505c173b9037a0b1d19a69',
#      'answers': [{'text': 'через биологические особенности',
#        'answer_start': 97}],
#      'question': 'Через что традиционно определяется понятие мужчина и женщина в западных культурах?'},
#     {'id': 'dfb527a9939c7bb8606bc562e0c925869aac14e8',
#      'answers': [{'text': 'бинарная', 'answer_start': 413}],
#      'question': 'Какая гендерная система подразумевает жёсткое соответствие приписанного человеку при рождении пола и гендерной роли?'},
#     {'id': 'a848e84106e18c5c8ebc2b8031e9343934d35d00',
#      'answers': [{'text': 'через биологические особенности',
#        'answer_start': 97}],
#      'question': 'Через что определяется понятие мужчина , как и женщина?'},
#     {'id': '7b719e5f48709a669eeb0f6efa4ca00616502e69',
#      'answers': [{'text': 'социальную группу, гендерную роль или гендерную идентичность',
#        'answer_start': 312}],
#      'question': 'Что обозначает понятие мужчина?'},
#     {'id': 'dac3d01634efa8472ece43e7c63efc14c41b2d1c',
#      'answers': [{'text': 'социальную группу, гендерную роль или гендерную идентичность',
#        'answer_start': 312}],
#      'question': 'Что прежде всего обозначает понятие мужчина во многих контекстах?'},
#     {'id': 'cc55d64b7175e37ab45e6b54edac71951cea00fd',
#      'answers': [{'text': 'через биологические особенности',
#        'answer_start': 97}],
#      'question': 'Как в западных культурах традиционно определяется понятие мужчина и женщина?'}]},
#   {'context': 'В 97 году Тацит стал одним из консулов-суффектов по заранее утверждённому списку. Ранее, в 96 году, Домициан был свергнут, императором стал Нерва. Из-за этого неясно, какой император составлял и утверждал список консулов на будущий год. Предполагается, что составлялся список Домицианом, а окончательно утверждался Нервой, поскольку известно, что консулами 69 года стали в основном люди, утверждённые ещё за шесть месяцев до нового года императором Нероном. Другими консулами стали именитые политики, полководцы и юристы. Их одобрение Нервой стало знаком, что новую власть поддерживают самые известные люди из представителей нобилитета и талантливых выходцев из низов и что новый император намерен опираться на них, не предпринимая радикальных изменений и не используя силу. Это было актуально, поскольку в Риме помнили о гражданской войне, которая охватила империю после падения династии Юлиев-Клавдиев. Состав консулов на 97 год показателен и тем, что почти все новые консулы были верны прежним принцепсам (до Домициана) и не принадлежали к сенатской оппозиции императорам. Для Тацита, сына прокуратора и всадника по рождению, это была вершина очень удачной карьеры. В месяцы консулата Тацита (будучи суффектом, он был одним из двух консулов не весь год) произошёл мятеж преторианцев под руководством Касперия Элиана, и историк был свидетелем или даже участником попыток урегулирования ситуации. Именно в дни мятежа Нерва усыновил популярного полководца Марка Ульпия Траяна, находившегося на Рейне, и послал ему письмо со строкой из Илиады Слёзы мои отомсти аргивянам стрелами твоими! . Известно и о том, что в 97 году Тацит произнёс погребальную речь на похоронах консула Луция Вергиния Руфа. Примерно в 100 году он вместе с Плинием Младшим участвовал в деле африканских провинциалов против проконсула Мария Приска — наместника, известного своими злоупотреблениями.',
#    'qas': [{'id': 'b9d8470cb27da5e6ae11931d9b0902d3bcd504c4',
#      'answers': [{'text': 'популярного полководца Марка Ульпия Траяна',
#        'answer_start': 1433}],
#      'question': 'Кого усыновил Нерва в дни мятежа?'},
#     {'id': '9307bd0b3460e18cc5122bb591765c47dfff0abf',
#      'answers': [{'text': 'В 97 году', 'answer_start': 0}],
#      'question': 'В каком Тацит стал одним из консулов-суффектов?'},
#     {'id': 'fcae6df256622e783be8fe7d870b4011e7a7efa7',
#      'answers': [{'text': 'в 96 году', 'answer_start': 89}],
#      'question': 'В каком году был свергнут Домициан?'},
#     {'id': 'b96143615e6eb871891ab6151441611d1bb223d3',
#      'answers': [{'text': 'консула Луция Вергиния Руфа',
#        'answer_start': 1667}],
#      'question': 'На чьих похоронах Тацит произнёс погребальную речь?'},
#     {'id': '375153ef259342b15bdc9099596b3cf1fc6e6798',
#      'answers': [{'text': 'Примерно в 100 году', 'answer_start': 1696}],
#      'question': 'В каком году Тацит вместе с Плинием Младшим участвовал в деле африканских провинциалов против проконсула Мария Приска?'}]},
#   {'context': 'К 1980 г уже отошли от панк-рока либо отодвинулись на задний план многие британские группы, активные в 1977—1979 годах. Новая волна британского панк-рока (UK 82) опиралась на наиболее радикальный панк 70-х (Crass и ранний Oi!). Самой известной группой, игравшей злой и агрессивный панк с металлизированными гитарами и антисоциальными текстами, стали The Exploited. Среди других ведущих английских панк-групп начала десятилетия — Anti-Nowhere League и G.B.H., ещё более ориентированные на металлический саунд. Однако больше всего повлияла на становление трэш-метала и даже грайндкора группа Discharge, отличавшаяся предельно быстрыми и тяжёлыми песнями из 3-4 строк и агрессивным вокалом. Несколько особняком среди британского панк-рока 80-х находились The Toy Dolls, игравшие юмористический рок-н-роллный панк-рок с влиянием американской группы The Dickies. Наконец, в своём роде уникальной стала лондонская группа The Pogues, которая впервые и крайне успешно соединила энергетику и буйство панк-рока с мелодикой ирландского фолка.',
#    'qas': [{'id': '5cf8c63c40edaeda5c4508e6a30e0be2ba5bb454',
#      'answers': [{'text': 'The Toy Dolls', 'answer_start': 752}],
#      'question': 'Какая группа играла юмористический рок-н-роллный панк-рок с влиянием американской группы The Dickies?'},
#     {'id': '13f6fd9c18f6138d16efd4f3f46159308f5b10ef',
#      'answers': [{'text': 'группа The Pogues', 'answer_start': 908}],
#      'question': 'Какая группа стала уникальной впервые и крайне успешно соединив энергетику и буйство панк-рока с мелодикой ирландского фолка?'},
#     {'id': '6f7ebbaf849cf56980dce4be3672f8374f3bca73',
#      'answers': [{'text': 'К 1980 г', 'answer_start': 0}],
#      'question': 'К какому году отошли от панк-рока многие британские группы, активные в 1977-1979 годах?'},
#     {'id': '6bb5c385019a3641b433e9889c199aa57b512de1',
#      'answers': [{'text': 'группа Discharge', 'answer_start': 583}],
#      'question': 'Какая группа больше всего повлияла на становление трэш-метала и даже грайндкора?'},
#     {'id': '9417a7b3fb18ab623b61794432e12b314b64ae6f',
#      'answers': [{'text': 'The Exploited', 'answer_start': 350}],
#      'question': 'Какая самая известная группа играла злой и агрессивный панк с металлизированными гитарами и антисоциальными текстами?'}]},
#   {'context': 'Венгерский экономист-кейнсианец Николас Калдор напротив исходит из предположения, что кривая технического прогресса будет себя хорошо вести . По его теории для капиталиста повышение процентов роста ТСК оправданно только до начала непропорционального роста производительности труда и таким образом повышение расходов на увеличение ТСК оправданно для капиталистов только до определённого значения. По этому по мнению Калдора доступная часть оставшейся прибыли может быть направлена на создание новых рабочих мест.',
#    'qas': [{'id': 'd5705d38b3935cd879c3abf753634dc878eaa535',
#      'answers': [{'text': 'до начала непропорционального роста производительности труда',
#        'answer_start': 220}],
#      'question': 'До какого момента оправданно повышение процентов роста ТСК?'},
#     {'id': 'fe295cb3bdf19f3f645d4d213380da40356f5005',
#      'answers': [{'text': 'для капиталиста', 'answer_start': 156}],
#      'question': 'Для кого повышение процентов роста ТСК оправданно только до начала непропорционального роста производительности труда?'},
#     {'id': 'b2cc0545f4a769a66a4fd21c8f98e1e7664fbc20',
#      'answers': [{'text': 'Николас Калдор', 'answer_start': 32}],
#      'question': 'Кто предположил, что кривая технического прогресса будет себя хорошо вести?'},
#     {'id': '4e765b72bf6caf7c742915e81c18268b9cb2012b',
#      'answers': [{'text': 'на создание новых рабочих мест',
#        'answer_start': 480}],
#      'question': 'На что может быть направлена доступная часть оставшейся прибыли, по мнению Калдора?'},
#     {'id': 'b89d86e7cd38c6cec747257c822e3634df1ba2fb',
#      'answers': [{'text': 'хорошо', 'answer_start': 127}],
#      'question': 'Как по предположению Николаса Калдора будет себя вести кривая технического прогресса?'}]},
#   {'context': 'Более 41 % площади страны составляют леса и лесные угодья, 39,58 % — пастбища. Растительный мир Черногории разнообразен: всего на территории страны зафиксировано 2833 вида растений, из них 212 — эндемики Балканского полуострова, а 22 — эндемики Черногории. Согласно Конституции Черногории, республика является экологичным государством , под различными природоохранными режимами находится 8,1 % территории (в том числе национальные заповедники Дурмитор, Ловчен, Биоградская гора, Скадарское озеро и Проклетье).',
#    'qas': [{'id': '6dc52b9413ec5003903e60e101590d1c28a4a871',
#      'answers': [{'text': 'экологичным государством', 'answer_start': 310}],
#      'question': 'Чем является республика, согласно Конституции Черногории?'},
#     {'id': '9be6d4f0743e4acc5810e40b17420121e898932a',
#      'answers': [{'text': '8,1 %', 'answer_start': 388}],
#      'question': 'Сколько процентов территории находится под природоохранными режимами?'},
#     {'id': 'c86a96da829eb5ada41c0587a5c4e671a7fb9808',
#      'answers': [{'text': 'Более 41 %', 'answer_start': 0}],
#      'question': 'Какую площадь Черногории занимают леса и угодья?'},
#     {'id': '0cf4b1fe8f5e498c0af7d36542ff2bb825ddb3cb',
#      'answers': [{'text': '2833', 'answer_start': 162}],
#      'question': 'Сколько видов растений зафиксировано на территории Черногории?'},
#     {'id': '30056d320a51f8b75d9851a8cad154a85a5b4e04',
#      'answers': [{'text': '39,58 %', 'answer_start': 59}],
#      'question': 'Какую площадь Черногории занимают пастбища?'}]},
#   {'context': 'Ярчайшим явлением в португальской литературе XX века стало творчество Жозе Сарамаго. Член некогда запрещённой Коммунистической партии Португалии, Сарамаго неизменно тяготеет к левому флангу. Его фантасмагорическая проза исполнена идеей всечеловеческого равенства и глубоким гуманизмом. Антиклерикальные воззрения автора не раз вызывали ожесточённые обвинения Католической церкви, что не помешало ему после публикации романа Евангелие от Иисуса стать лауреатом Нобелевской премии по литературе 1998 года.',
#    'qas': [{'id': '7148a4e592f0ea1379c55b531cb0c5f1d0755595',
#      'answers': [{'text': 'после публикации романа Евангелие от Иисуса',
#        'answer_start': 400}],
#      'question': 'После чего Жозе Сарамаго стал лауреатом Нобелевской премии по литературе 1998 года?'},
#     {'id': 'd74c3101af014591233e61769ddc04cbeaa3d953',
#      'answers': [{'text': 'творчество Жозе Сарамаго', 'answer_start': 59}],
#      'question': 'Что стало ярчайшим явлением в португальской литературе XX века?'},
#     {'id': '2174908cb60475cffda91c54abed5d4e17fd142e',
#      'answers': [{'text': 'к левому', 'answer_start': 174}],
#      'question': 'К какому фланг неизменно тяготеет Жозе Сарамаго?'}]},
#   {'context': 'В 1940-х годах на фоне ужасов Второй мировой войны жанр становится по-большей части ориентированными на внушение ужаса, а не на его изображение. В это время Вэл Льютон выпустил несколько малобюджетных фильмов для RKO Pictures, которые получились очень атмосферными: Люди-кошки (1942), Я гуляла с зомби (1943), и Похитители тел (1945), а Марк Робсон выпускает фильм Седьмая жертва (1943). Работавший помощником у Льютона режиссёр Роберт Уайз в интервью программе 100 лет ужаса давал высокую оценку этим картинам, отметив, что Льютон компенсировал сковывающие инициативу требования продюсеров и цензуры умелым преподношением материала в эстетике экспрессионизма.',
#    'qas': [{'id': '6c370c3fd150b2706e8fc2a6bd62d95afe312d40',
#      'answers': [{'text': 'Марк Робсон', 'answer_start': 337}],
#      'question': 'Кто выпустил фильм Седьмая жертва (1943)?'},
#     {'id': '4e1ab8d002cdfa9bbddbb797a15bf6fe525a8aa5',
#      'answers': [{'text': 'Вэл Льютон', 'answer_start': 157}],
#      'question': 'Кто выпустил серию малобюджетных фильмов для RKO Pictures ( Люди-кошки (1942), Я гуляла с зомби (1943), и Похитители тел (1945))?'},
#     {'id': '92141c10461a2671e6c009de0b0335a4bf333935',
#      'answers': [{'text': 'для RKO Pictures', 'answer_start': 209}],
#      'question': 'Для какой студии Вэл Льютон выпустил несколько малобюджетных фильмов ( Люди-кошки (1942), Я гуляла с зомби (1943))?'},
#     {'id': '6f45423730dc0d9b88d0729ac70693b8fcc747ab',
#      'answers': [{'text': 'Роберт Уайз', 'answer_start': 429}],
#      'question': 'Кто в интервью программе 100 лет ужаса давал высокую оценку картинам Вэла Льютона?'},
#     {'id': '0e4acd052d0f5e0749795224918b8310e8b41b28',
#      'answers': [{'text': '1943', 'answer_start': 381}],
#      'question': 'В каком году режиссер Марк Робсон снял фильм ужасов Седьмая жертва?'},
#     {'id': '469d83e9f52c2af29be94aa7a240be657581e8fe',
#      'answers': [{'text': 'Вэл Льютон', 'answer_start': 157}],
#      'question': 'Кто выпустил несколько малобюджетных фильмов для RKO Pictures, которые получились очень атмосферными?'},
#     {'id': '149301b0a0ee362b7fbe2c6521598396cc39655f',
#      'answers': [{'text': 'В 1940-х годах', 'answer_start': 0}],
#      'question': 'В каких годах жанр ужасов становится по-большей части ориентированными на внушение ужаса, а не на его изображение?'},
#     {'id': '1584d352de0e8610e8ebda8820777a27ac74dc5f',
#      'answers': [{'text': 'программе 100 лет ужаса давал',
#        'answer_start': 452}],
#      'question': 'В какой программе Роберт Уайз рассказывал о фильмах Вэла Льютона?'},
#     {'id': '71b68d20bfbd0ffef207d2f120197c75c6ef8305',
#      'answers': [{'text': 'Второй мировой', 'answer_start': 30}],
#      'question': 'На фоне какой войны жанр ужасов становится по-большей части ориентированными на внушение ужаса, а не на его изображение?'},
#     {'id': 'b4246ec4c1400d51ca960a86c1dc72ae12879311',
#      'answers': [{'text': ': Люди-кошки (', 'answer_start': 264}],
#      'question': 'Какие фильмы снял Вэл Льютон в начале 1940-х годов?'},
#     {'id': 'a0d11ba588a210f11fbe81aea098a8d11d9586cb',
#      'answers': [{'text': ': Люди-кошки (', 'answer_start': 264}],
#      'question': 'Какие атмосферные фильмы выпустил Вэл Льютон для RKO Pictures?'},
#     {'id': '8d45a4e4affc9d8818d22f088eeb88f0d228bc53',
#      'answers': [{'text': 'на внушение ужаса', 'answer_start': 101}],
#      'question': 'На вызов каких эмоций у зрителей стали ориентироваться создатели фильмов ужасов после Второй мировой войны?'}]},
#   {'context': 'Во многих языках одно и то же слово обозначает как мужчину, так и человека вообще, например англ. man, фр. homme, рус. молодой человек (в обращении к мужчине) и др. В современных гуманитарных науках этот факт понимается как одно из ключевых проявлений андроцентризма — представления о мужчине и мужском как о норме, относительно которой женщина и женское рассматриваются как отклонение. К другим проявлениям андроцентризма в языке относится, например, игнорирование женщин за счёт использования общего мужского рода и местоимения он для обозначения человека вне зависимости от гендера.',
#    'qas': [{'id': '0f408e0de023704c1a6bcf200702a7e5af2c446e',
#      'answers': [{'text': 'игнорирование женщин', 'answer_start': 452}],
#      'question': 'Что является проявлением андроцентризма в языке?'},
#     {'id': '8790ceec7bee21e2dc9a721097363626a25f1a41',
#      'answers': [{'text': 'представления о мужчине и мужском как о норме',
#        'answer_start': 269}],
#      'question': 'Что такое андроцентризм?'},
#     {'id': '0a629b039a2858d3adc257f9e5eaba9bee94fb80',
#      'answers': [{'text': 'женщина и женское', 'answer_start': 337}],
#      'question': 'Что рассматривается как отклонение относительно андроцентризма?'},
#     {'id': '64dd2d46464b01dd9595c887c21be9ef12b77bf9',
#      'answers': [{'text': 'местоимения он', 'answer_start': 518}],
#      'question': 'Какое местоимение используется в андроцентризме для обозначения человека вне зависимости от гендера?'},
#     {'id': 'ea5648cd36e09ac96ea02ab8686bc6b57c159c4f',
#      'answers': [{'text': 'Во многих', 'answer_start': 0}],
#      'question': 'В каких языках одно и то же слово обозначает как мужчину, так и человека вообще?'},
#     {'id': '51f75680ff3c135a5274ae6d406d5c0fed59c46e',
#      'answers': [{'text': 'man', 'answer_start': 98}],
#      'question': 'Как по-английски звучит мужчина?'},
#     {'id': '4419ca2ac3b2f3e96e8f828f377c5ce5581c9d67',
#      'answers': [{'text': 'homme', 'answer_start': 107}],
#      'question': 'Как по-французски звучит мужчина?'},
#     {'id': '6bb3c478f4dd7f55bda6ff9c44610cbd6cc49d19',
#      'answers': [{'text': 'как отклонение', 'answer_start': 371}],
#      'question': 'Как рассматривается женщина и женское относительно представления о мужчине и мужском как о норме?'},
#     {'id': 'eeb741f75c001f382f8516e813cd318ed34308fd',
#      'answers': [{'text': 'игнорирование женщин', 'answer_start': 452}],
#      'question': 'Какие проявления андроцентризма наблюдаются в языке?'},
#     {'id': '86203eb8bbce4178bc612e43407bf2092b891afa',
#      'answers': [{'text': 'представления о мужчине и мужском как о норме',
#        'answer_start': 269}],
#      'question': 'Что означает андроцентризм?'}]},
#   {'context': 'В античную эпоху Тацит не был очень известен. Хотя его друг Плиний Младший предсказывал в письмах, что его произведения будут бессмертными, в сочинениях других интеллектуалов античной эпохи его имя практически не встречается. Всплеск популярности Тацита пришёлся на краткое правление императора Марка Клавдия Тацита, который считал себя потомком историка и повелел всем библиотекам в империи иметь экземпляры его сочинений. Кроме того, известный историк конца IV века Аммиан Марцеллин начал повествование в Деяниях (лат. Res Gestae) с 96 года (убийство Домициана и начало правления Нервы), то есть с момента окончания повествования в Истории Тацита. Был хорошо знаком с его сочинениями и Павел Орозий. В своей Истории против язычников он нередко использует Тацита как источник информации, однако указывает на недостоверные сведения и на нежелание историка разобраться в истории, связанной с разрушением Содома и Гоморры. Тертуллиан называл его лжецом за рассказ об обычаях евреев. В то же время, Кассиодор знает лишь некоего Корнелия.',
#    'qas': [{'id': 'fdaf2a5767940c1daa4b195618706c4181a4d819',
#      'answers': [{'text': 'В античную эпоху', 'answer_start': 0}],
#      'question': 'Когда Тацит не был очень известен?'},
#     {'id': 'cb3a2fe498b4975c4cc79380218ff83744c41569',
#      'answers': [{'text': 'на краткое правление императора Марка Клавдия Тацита',
#        'answer_start': 263}],
#      'question': 'На какое событие пришелся всплеск популярности Тацита?'},
#     {'id': '7d3154454ec00e9efed32dd8c9bce4e41d9c9243',
#      'answers': [{'text': 'Плиний Младший', 'answer_start': 60}],
#      'question': 'Кто предсказывал в письмах, что произведения Тацита будут бессмертными?'},
#     {'id': '47b6ea1ecae3f78d3a13ef3cfe5283adaa1b4130',
#      'answers': [{'text': 'Тертуллиан', 'answer_start': 921}],
#      'question': 'Кто называл Тацита лжецом за рассказ об обычаях евреев?'}]},
#   {'context': 'Кроме художественного прозрения в сущность мира, есть ещё другой путь к освобождению себя от страданий, это — углубление в моральный смысл бытия. Πρώτον ψευδος Канта — голословное принятие абсолютной обязательности нравственного закона, на самом деле нравственный закон гипотетичен, а не категоричен: его императивный характер Кант втихомолку заимствовал у Моисея; на самом деле категорический императив — фетиш. Морали приходится иметь дело с действительными поступками человека, а не с априористической постройкой карточных домиков… . Кроме бессодержательного формализма, этика Канта страдает ещё, по мнению Шопенгауэра, тем, что ограничивается исследованием только моральных отношений между людьми, совершенно забывая о животных.',
#    'qas': [{'id': '36feb153b4ed1595e82c4e2ff75eaa255318ac2c',
#      'answers': [{'text': 'у Моисея', 'answer_start': 355}],
#      'question': 'У кого Кант негласно заимствовал императивный характер нравственного закона?'},
#     {'id': '0e9c1d74303af95c5c9511c1f3396b4453d99c3f',
#      'answers': [{'text': 'абсолютной обязательности нравственного закона',
#        'answer_start': 189}],
#      'question': 'Бездоказательным принятием чего по сути является???????????? Канта?'},
#     {'id': 'cd4d9f3b67617cf9aad663f376fb259dde025a04',
#      'answers': [{'text': 'с действительными поступками человека',
#        'answer_start': 442}],
#      'question': 'С чем имеет дело мораль, по мнению Шопенгауэра?'},
#     {'id': '7d7e908c577e431bbc1e085ed5519969155804ed',
#      'answers': [{'text': 'исследованием только моральных отношений между людьми',
#        'answer_start': 647}],
#      'question': 'Чем, как утверждал Шопенгауэр, ограничено учение Канта?'},
#     {'id': '942779e9eb86c4d4de3251613351917d4ce73b89',
#      'answers': [{'text': 'углубление в моральный смысл бытия',
#        'answer_start': 110}],
#      'question': 'Какой существует способ освобождения себя от страданий, помимо художественного прозрения в сущность мира?'}]},
#   {'context': 'Для увеличения пропускной способности линий в конце 2000-х начата реконструкция участков дороги с прокладкой дополнительных главных путей, не осуществлявшаяся более 20 лет. Первым в 2007—2008 построен третий путь Горьковского направления Москва — Кусково, частично на существовавших малодеятельных путях, вместе с существовавшим третьим путём до Железнодорожной образовался отдельный путь для скоростных поездов. С начала 2010-х и увеличением финансирования фронт работ расширился: начали строиться 2-й путь Наугольный — Иванцево Большого кольца, 3-й и 4-й пути Смоленского направления до Одинцово, 4-й путь Горьковского до Железнодорожной, 4-й путь Ярославского от Мытищ до Пушкино, 2-й путь Павелецкого от Авиационной до Аэропорта-Домодедово.',
#    'qas': [{'id': '67146e583d533fd63ec066a5f8e04cf56e76d0bf',
#      'answers': [{'text': '3-й и 4-й пути', 'answer_start': 547}],
#      'question': 'Какие пути Смоленского направления Московской железной дороги были построены в начале 2010 года?'},
#     {'id': '1a484ff836e054a376fd274614764e05e93e1c36',
#      'answers': [{'text': 'Для увеличения пропускной способности линий',
#        'answer_start': 0}],
#      'question': 'Для чего в конце 200-х начался ремонт участков Московской железной дороги со строительством новых путей?'},
#     {'id': '4eade836ae2222cc6b29aadcd6f510ae6ecb7e51',
#      'answers': [{'text': 'третий путь Горьковского направления Москва — Кусково',
#        'answer_start': 201}],
#      'question': 'Какой путь построен первым в 2007-2008 годах?'},
#     {'id': 'dc7e14f98bad95557fe1e0b4982ae8f1e5971004',
#      'answers': [{'text': 'С начала 2010-х', 'answer_start': 413}],
#      'question': 'Когда начали строиться 2-й путь Наугольный — Иванцево Большого кольца, 3-й и 4-й пути Смоленского направления до Одинцово, 4-й путь Горьковского до Железнодорожной, 4-й путь Ярославского от Мытищ до Пушкино, 2-й путь Павелецкого от Авиационной до Аэропорта-Домодедово?'},
#     {'id': '49584099a0f350952ec1dc8f5fdd961d29b6a046',
#      'answers': [{'text': 'Для увеличения пропускной способности линий',
#        'answer_start': 0}],
#      'question': 'Для чего была начата в конце 2000-х реконструкция участков дороги с прокладкой дополнительных главных путей?'},
#     {'id': 'c3a708adc277ba88664ca5fc7ff462178314bf77',
#      'answers': [{'text': 'в 2007—2008', 'answer_start': 180}],
#      'question': 'Когда был построен третий путь Горьковского направления Москва — Кусково?'},
#     {'id': '435544024f13e5c0afd3a6de159aab91fb1ab7e5',
#      'answers': [{'text': 'более 20 лет', 'answer_start': 159}],
#      'question': 'Сколько не осуществлялась начатая в конце 2000-х реконструкция участков дороги с прокладкой дополнительных главных путей?'}]},
#   {'context': 'Возвращаясь к древнеримским идеалам, Ренессанс упорно видел во всем неримском печать варварства , хотя с инженерной точки зрения готические соборы, несомненно, представляли большой шаг вперёд по сравнению с романскими соборами. Поэтому на рубеже XIX века, когда вслед за крахом Французской революции по Европе прокатилась волна разочарования классицистическим рационализмом и идеалами Просвещения, востребованной оказалась естественная (в руссоистском понимании), природная архитектура, предположительно сохранившая под покровом христианской догматики дух Европы, существовавшей до прихода на север Европы римлян.',
#    'qas': [{'id': '369b5ca9d431eb3d87b0c06a2fbb58ae7f19de2d',
#      'answers': [{'text': 'печать варварства', 'answer_start': 78}],
#      'question': 'Что видел Ренессанс в том что не относится к римскому?'},
#     {'id': '1db248e1957feeae36b44cc5d9e64a39fb44a795',
#      'answers': [{'text': 'волна разочарования классицистическим рационализмом и идеалами Просвещения',
#        'answer_start': 322}],
#      'question': 'Какое событие прокатилось по Европе после революции?'},
#     {'id': 'b234ecbb77954ec24a1d7095318421039237cc04',
#      'answers': [{'text': 'на рубеже XIX века', 'answer_start': 236}],
#      'question': 'Когда совершился крах французской революции?'},
#     {'id': '7d0c6f5ee4bbd80b4e3f90e385fc03e6fd999d35',
#      'answers': [{'text': 'христианской догматики', 'answer_start': 529}],
#      'question': 'Что сохраняло дух Европы до прихода на север римлян?'},
#     {'id': '6e24231f9723d017e6e00cfe7f6d66be726a8527',
#      'answers': [{'text': 'с романскими соборами', 'answer_start': 205}],
#      'question': 'По сравнении с какими строениями готические были на шаг впереди?'}]},
#   {'context': 'Положение группы членистоногих в таксономической иерархии неоднозначно. С одной стороны, некоторые авторы (например Сидни Ментон) предложили версию, что разные подтипы членистоногих независимо произошли от червеподобных предков (другими словами, предполагалась полифилия членистоногих). В частности, эти авторы считали, что подтип трахейные (Uniramia) ближе к онихофорам (Onychophora), чем к остальным членистоногим. Однако большинство учёных не приняло эту точку зрения. Это противоречит и генетическим исследованиям.',
#    'qas': [{'id': '69a5986e7ac366c919392f6f580f85f5c66c9f7e',
#      'answers': [{'text': 'от червеподобных предков', 'answer_start': 203}],
#      'question': 'От кого, согласно одной из версий, независимо произошли разные подтипы членистоногих?'},
#     {'id': 'cd85b08f83c17c99d6845b75b39acf9bb8bf0e66',
#      'answers': [{'text': 'разные подтипы членистоногих независимо произошли от червеподобных предков',
#        'answer_start': 153}],
#      'question': 'Что предполагает полифилия членистоногих?'},
#     {'id': '0eb1c6cd5452148121209a648470ff48add83b28',
#      'answers': [{'text': 'полифилия членистоногих', 'answer_start': 261}],
#      'question': 'Какая версия происхождения членистоногих предполагалась Сидни Ментоном?'}]},
#   {'context': 'В 1847 году Пирогов уехал в действующую армию на Кавказ, так как хотел проверить в полевых условиях разработанные им операционные методы. На Кавказе он впервые применил перевязку бинтами, пропитанными крахмалом; крахмальная перевязка оказалась удобнее и прочнее, чем применявшиеся раньше лубки. В это же время Пирогов, первым в истории медицины, начал оперировать раненых с эфирным обезболиванием в полевых условиях, проведя около 10 тыс. операций под эфирным наркозом. В октябре 1847 года он получил чин действительного статского советника.',
#    'qas': [{'id': 'ab76254e9f33172c2c32539b5a837b16de5df7ac',
#      'answers': [{'text': 'начал оперировать раненых с эфирным обезболиванием',
#        'answer_start': 346}],
#      'question': 'Что впервые в истории медицины сделал Пирогов?'},
#     {'id': '74a31594476ee032eef3202cce38d4f7a61bae51',
#      'answers': [{'text': 'около 10 тыс.', 'answer_start': 425}],
#      'question': 'Сколько операций провел Пирогов?'},
#     {'id': '621d45902379e0d69d3a3e762d5ab134c81adf3d',
#      'answers': [{'text': 'В 1847 году', 'answer_start': 0}],
#      'question': 'В каком году Пирогов уехал в армию на Кавказ?'},
#     {'id': 'e8f01a1eba7cc292295dcf42112fe5f2fcc1704d',
#      'answers': [{'text': 'проверить в полевых условиях разработанные им операционные методы',
#        'answer_start': 71}],
#      'question': 'Что Пирогов хотел сделать в армии?'}]},
#   {'context': 'Ледяная крупа — твёрдые осадки ливневого характера, выпадающие при температуре воздуха от −5 до +10° в виде прозрачных (или полупрозрачных) ледяных крупинок диаметром 1—3 мм; в центре крупинок — непрозрачное ядро. Крупинки достаточно твёрдые (раздавливаются пальцами с некоторым усилием), при падении на твёрдую поверхность отскакивают. В ряде случаев крупинки могут быть покрыты водяной плёнкой (или выпадать вместе с капельками воды), и если температура воздуха ниже нуля градусов, то падая на предметы, крупинки смерзаются и образуется гололёд.',
#    'qas': [{'id': 'b7ac14685d88fb8aa20d6573eec6dba0e006374f',
#      'answers': [{'text': 'Ледяная крупа', 'answer_start': 0}],
#      'question': 'Как называются твёрдые осадки ливневого характера, выпадающие при температуре воздуха от?5 до +10°?'},
#     {'id': '14bd8a7ecb7c9bdef979d0fa95b24b7dc5c6971d',
#      'answers': [{'text': 'от −5 до +10°', 'answer_start': 87}],
#      'question': 'При какой температуре воздуха выпадает ледяная крупа?'},
#     {'id': '5696702cbcd58508f751eee144f3d09509826bd0',
#      'answers': [{'text': 'диаметром 1—3 мм', 'answer_start': 157}],
#      'question': 'Какого диаметра ледяные крупинки, выпадающие при температуре воздуха от?5 до +10°?'},
#     {'id': '60dab8bb90f0cec02a12fb03e33d19fa5da2bb05',
#      'answers': [{'text': 'отскакивают', 'answer_start': 324}],
#      'question': 'При падении на твердую поверхность как ведут себя ледяные крупинки?'},
#     {'id': 'c34137bed0c9f7dd6189c8f2bfd250e23a795c27',
#      'answers': [{'text': 'смерзаются', 'answer_start': 515}],
#      'question': 'Как ведут себя крупинки, падая на предметы, если температура воздуха ниже нуля градусов?'}]},
#   {'context': 'В соответствии с Законом РФ от 2002 года Об особенностях управления и распоряжения имуществом железнодорожного транспорта , с 2003 года Московская железная дорога, как и другие железные дороги России, потеряла статус юридического лица, прибыль от хозяйственной деятельности дороги перечисляется на единый расчётный счёт ОАО РЖД , начальник дороги действует по доверенности президента ОАО РЖД . С завершающим этапом реформирования отрасли в 2012 году каждая из 16 дорог стала функционировать в режиме Регионального центра корпоративного управления (РЦКУ). Московская дорога — это РЦКУ № 1.',
#    'qas': [{'id': '1544c2cca95fda354cdaf694567b5a53cfe5ece4',
#      'answers': [{'text': 'Московская железная дорога', 'answer_start': 136}],
#      'question': 'Кто потерял статус юридического лица, прибыль от хозяйственной деятельности дороги перечисляется на единый расчётный счёт ОАО РЖД , начальник дороги действует по доверенности президента ОАО РЖД в соответствии с Законом РФ от 2002 года Об особенностях управления и распоряжения имуществом железнодорожного транспорта?'},
#     {'id': '08e6b03b48283e287a7f869134efec62892b9610',
#      'answers': [{'text': 'в режиме Регионального центра корпоративного управления',
#        'answer_start': 491}],
#      'question': 'В каком режиме каждая из 16 дорог стала функционировать в 2012 году?'},
#     {'id': 'ff29f6efcbaaa587dd1404937228acf8d2d753af',
#      'answers': [{'text': 'в 2012 году', 'answer_start': 438}],
#      'question': 'В каком году каждая из 16 дорог стала функционировать в режиме Регионального центра корпоративного управления (РЦКУ)?'},
#     {'id': 'b600bd2cdd3e1f93b353e59367bf1f4a9aef0b04',
#      'answers': [{'text': 'с 2003 года', 'answer_start': 124}],
#      'question': 'С какого года Московская железная дорога, как и другие железные дороги России, потеряла статус юридического лица, прибыль от хозяйственной деятельности дороги перечисляется на единый расчётный счёт ОАО РЖД , начальник дороги действует по доверенности президента ОАО РЖД?'},
#     {'id': '057cc2e736cbeb47fd704d5c8b041d4717bec1d9',
#      'answers': [{'text': 'начальник дороги', 'answer_start': 330}],
#      'question': 'Кто действует доверенности президента ОАО РЖД?'},
#     {'id': '876c952e35401883a0aa065c75470928ff27f07b',
#      'answers': [{'text': 'на единый расчётный счёт', 'answer_start': 295}],
#      'question': 'На какой счёт перечисляется прибыль от хозяйственной деятельности железной дороги?'},
#     {'id': 'd8ecd578af3d403f4dd03a064d9391461cadfba2',
#      'answers': [{'text': 'президента ОАО РЖД', 'answer_start': 373}],
#      'question': 'По чьей доверенности действует начальник железной дороги?'},
#     {'id': '9a73e2b32a60b47d1cae7400f28262b2cda2b54d',
#      'answers': [{'text': 'Законом РФ от 2002 года', 'answer_start': 17}],
#      'question': 'В соответствии с каким законом железная дорога перестаёт быть юридическим лицом?'},
#     {'id': '4567523a95ecf5b90dd4f69b5f669c118f5eaa44',
#      'answers': [{'text': 'с 2003 года', 'answer_start': 124}],
#      'question': 'Какого года был создан Закон РФ при котором железная дорога теряет статус юридического лица?'},
#     {'id': '15c26adff9859a913f222283c6235d59fcdf815f',
#      'answers': [{'text': 'в режиме Регионального центра корпоративного управления',
#        'answer_start': 491}],
#      'question': 'В чьём режиме начали функционировать железные дороги РФ с 2012 года?'}]},
#   {'context': 'Также одной из причин возникновения приливов и отливов является суточное (собственное) вращение Земли. Массы воды мирового океана, имеющие форму эллипсоида, большая ось которого не совпадает с осью вращения Земли, участвуют в её вращении вокруг этой оси. Это ведёт к тому, что в системе отсчёта, связанной с земной поверхностью, по океану бегут по взаимно противоположным сторонам земного шара две волны, приводящие в каждой точке океанского побережья к периодическим, два раза в сутки повторяющимся явлениям отлива, чередующихся с приливами.',
#    'qas': [{'id': '062816d163e6a0adb5d0aebc9c07005e255a3b8a',
#      'answers': [{'text': 'приливов и отливов', 'answer_start': 36}],
#      'question': 'Причиной возникновения чего является суточное вращение Земли?'},
#     {'id': '8698f16ef908616fef618312e648df827ceca648',
#      'answers': [{'text': 'не совпадает', 'answer_start': 178}],
#      'question': 'Как расположена большая ось Мирового океана относительно оси вращения Земли?'},
#     {'id': '617098d3982e1cbaa3f8ef7f4a54cb9a8cd8ae4a',
#      'answers': [{'text': '. Массы воды мирового океана, имеющие форму эллипсоида',
#        'answer_start': 101}],
#      'question': 'Какую форму имеют массы воды мирового океана?'},
#     {'id': '0f517aa619850ffdbc3561d971aec17d09947b5d',
#      'answers': [{'text': 'два', 'answer_start': 469}],
#      'question': 'Сколько раз в сутки повторяются явления отлива?'},
#     {'id': '086a9654ebab973082379b728bef2436bbc7d90a',
#      'answers': [{'text': 'две', 'answer_start': 394}],
#      'question': 'Сколько волн бежит по взаимно противоположным сторонам земного шара?'},
#     {'id': '4e9ba961655b613bc4bfbde9083642ef174d1da3',
#      'answers': [{'text': 'эллипсоида', 'answer_start': 145}],
#      'question': 'Какую форму имеют массы мирового океана?'},
#     {'id': '27d0a2cb8ca319e22b5791c8c8bc71bf3b197999',
#      'answers': [{'text': 'суточное (собственное) вращение Земли',
#        'answer_start': 64}],
#      'question': 'Причина возникновения приливов и отливов?'},
#     {'id': 'ab5ffd7478c28b9a5b11e1206de0869cfcb2c26d',
#      'answers': [{'text': 'суточное (собственное) вращение Земли',
#        'answer_start': 64}],
#      'question': 'Что является одной из причин возникновения приливов и отливов?'},
#     {'id': '1ccedb7d63c55afaa423a1b91afbb9209f59024f',
#      'answers': [{'text': 'с приливами', 'answer_start': 530}],
#      'question': 'С чем чередуются явления отлива?'}]},
#   {'context': 'Праславянский язык функционировал в догосударственный период истории славян, когда господствовал родоплеменной общественный строй. Существенные изменения произошли в период раннего феодализма. В XII—XIII вв. происходила дальнейшая дифференциация славянских языков, произошла утрата свойственных праславянскому языку сверхкратких (редуцированных) гласных ъ и ь. В одних случаях они исчезли, в других перешли в гласные полного образования. В результате произошли существенные изменения в фонетическом и морфологическом строе славянских языков, в их лексическом составе.',
#    'qas': [{'id': '2750cc602b6fb0b4c22bfc55a192bc606a7cf779',
#      'answers': [{'text': 'Праславянский', 'answer_start': 0}],
#      'question': 'Какой язык функционировал в догосударственный период истории славян?'},
#     {'id': '03716d72f23e827961fae6cbd8b6f93067f43389',
#      'answers': [{'text': 'образования. В результате произошли существенные изменения в фонетическом и морфологическом',
#        'answer_start': 425}],
#      'question': 'В каком строе славянских языков произошли существенные изменения?'},
#     {'id': 'bc1efac8d29b12378ab2f7afe597c3234560ed59',
#      'answers': [{'text': 'ъ и ь', 'answer_start': 354}],
#      'question': 'Утрата каких свойственных праславянскому языку сверхкратких (редуцированных) гласных произошла?'},
#     {'id': '7779bfe84312baef883f40e7f07f859445e58936',
#      'answers': [{'text': 'В XII—XIII вв.', 'answer_start': 193}],
#      'question': 'В каком веке происходила дальнейшая дифференциация славянских языков?'}]},
#   {'context': 'В дополнение к трем основным должностям, есть несколько экзотических, которые можно рассматривать как ступени, следующие после полного профессора. Например, в университете для профессора может быть создана почётная должность выдающийся профессор (англ. distinguished professor), зарплата которого выше, чем у полного профессора (англ. full professor) за счет средств университета, частных лиц, фирм и учредителей. В ряде университетов преподавателям, имевшим звания полный профессор или выдающийся профессор и внесшим существенный вклад в науку, при выходе на пенсию присваивается звание заслуженный профессор (профессор-эмерит, англ. professor emeritus).',
#    'qas': [{'id': '7f3935af2a8f0179440ee14e699caaed0097bb6b',
#      'answers': [{'text': 'звание заслуженный профессор',
#        'answer_start': 581}],
#      'question': 'При выходе на пенсию преподавателя, имевшего звание полный профессор или выдающийся профессор , какое звание ему может быть присвоено?'},
#     {'id': 'c880d5dafb2ced356f153503221e15d4265fc9ad',
#      'answers': [{'text': 'профессор-эмерит', 'answer_start': 611}],
#      'question': 'Как еще называется заслуженный профессор?'},
#     {'id': '8ad4d59fdbd062cdb38d32669c46361faaff8378',
#      'answers': [{'text': 'звание заслуженный профессор',
#        'answer_start': 581}],
#      'question': 'Какая должность присваивается профессору после звания полный профессор?'},
#     {'id': '4bff38f28f6114dbee536d0a5b6b25aa03221ab1',
#      'answers': [{'text': 'при выходе на пенсию', 'answer_start': 546}],
#      'question': 'По каким причинам присваивается звание заслуженный профессор?'},
#     {'id': 'b02c3d8087ef5b2fdfdfdaf9f20cffa46f280f8e',
#      'answers': [{'text': 'за счет средств университета, частных лиц, фирм и учредителей',
#        'answer_start': 351}],
#      'question': 'За счет каких средств зарплата у выдающегося профессора выше, чем у полного профессора?'}]},
#   {'context': 'Франкфурт был финансовым центром Германии на протяжении столетий и является местом сосредоточения крупных банков и брокерских контор. Экономика Франкфурта базируется на трех китах — финансах, транспорте и ярмарочной деятельности. Франкфуртская биржа — крупнейшая в Германии и одна из наиболее значимых в мировой экономике. Во Франкфурте располагается Европейский Центральный Банк (нем. Europäische Zentralbank), который определяет денежно-кредитную политику стран Еврозоны и Федеральный Банк Германии (нем. Deutsche Bundesbank). Порядка 300 национальных и иностранных банков имеют представительства во Франкфурте, включая штаб-квартиры крупнейших немецких банков.',
#    'qas': [{'id': '17eb2b5ef0be139e778f97e29d3b9afe9de8b26d',
#      'answers': [{'text': 'Европейский Центральный Банк',
#        'answer_start': 351}],
#      'question': 'Какой банк располагается во Франкфурте?'},
#     {'id': '1e6578b13a2188232cd0b2bf0401bab741425387',
#      'answers': [{'text': 'Франкфурт', 'answer_start': 0}],
#      'question': 'Какой город является финансовым центром Германии на протяжении столетий?'},
#     {'id': '061b3b821821f2cf226f1ee31f772cab84a14c98',
#      'answers': [{'text': 'финансах, транспорте и ярмарочной деятельности',
#        'answer_start': 182}],
#      'question': 'На каких трех китах базируется экономика Франкфурта?'},
#     {'id': '3b6a733899125305848868fbbbcc7a126bec92e2',
#      'answers': [{'text': 'Порядка 300', 'answer_start': 529}],
#      'question': 'Сколько национальных и иностранных банков имеют представительства во Франкфурте?'}]},
#   {'context': 'Клеточные мембраны обладают избирательной проницаемостью: через них медленно диффундируют глюкоза, аминокислоты, жирные кислоты, глицерол и ионы, причем сами мембраны в известной мере активно регулируют этот процесс — одни вещества пропускают, а другие нет. Существует четыре основных механизма для поступления веществ в клетку или вывода их из клетки наружу: диффузия, осмос, активный транспорт и экзо- или эндоцитоз. Два первых процесса носят пассивный характер, то есть не требуют затрат энергии; два последних — активные процессы, связанные с потреблением энергии.',
#    'qas': [{'id': 'cbb65460b30f80a9d471caf97a340ea3b549425d',
#      'answers': [{'text': 'глюкоза, аминокислоты, жирные кислоты, глицерол и ионы',
#        'answer_start': 90}],
#      'question': 'Какие вещества распространяются через клеточные мембраны?'},
#     {'id': '1e11aad32d7b5e1bbae261c8360771456f8f40a6',
#      'answers': [{'text': 'избирательной проницаемостью', 'answer_start': 28}],
#      'question': 'Каким важным свойством обладают клеточные мембраны?'},
#     {'id': '8319bdbe20dc7fc38790ac9827fca67700a9d896',
#      'answers': [{'text': 'активно', 'answer_start': 184}],
#      'question': 'Как клеточные мембраны управляют процессом перемещения веществ в клетках?'},
#     {'id': 'db329337fd50d53f0b4c68671135780ae8f2f2dd',
#      'answers': [{'text': 'активный транспорт и экзо- или эндоцитоз',
#        'answer_start': 377}],
#      'question': 'Каковы главные пути проникновения веществ в клетку и вывода их из нее?'}]},
# ...
#     {'id': '60a6fa9088829c6b5e8622b6316c9e79adf7e775',
#      'answers': [{'text': 'Гражданский проспект', 'answer_start': 213}],
#      'question': 'Какая улица главная в городе?'}]},
#   {'context': 'В 1457—1458 годах Энеа Сильвио Пикколомини (в скором времени он стал папой римским под именем Пия II) использовал рукопись для написания полемического сочинения (подробнее см. ниже). Дальнейшая судьба этого манускрипта (условно его называют Codex Hersfeldensis ) неизвестна. В XV веке было сделано множество рукописных копий Диалогов и Агриколы , на основании которых были напечатаны первые современные издания. Долгое время на основании существования двух разных традиций прочтения отдельных фраз в рукописных копиях XV века и первых печатных изданиях предполагалось, что существовало две исходных рукописи для малых произведений Тацита — рукопись X и рукопись Y . Однако в 1902 году в частной библиотеке в Ези был обнаружен манускрипт, получивший обозначение Codex Aesinas (Рукопись Ези). Вместе с сочинениями Тацита в этой рукописи содержался также перевод Дневника Троянской войны Диктиса Критского с древнегреческого на латинский язык, выполненный в IV веке неким Септимием. Манускрипт примечателен тем, что часть Агриколы написана почерком XV века, а часть — каролингским минускулом IX века. Кроме того, на полях записано большое количество альтернативных прочтений, в том числе и таких подробных, которые не мог оставить простой переписчик. Предполагается, что переписчик либо имел под рукой два манускрипта с разными прочтениями, либо переписывал текст со всеми маргиналиями. В почерке же XV века обычно признают руку Стефано Гварнери, основателя библиотеки Ези. Из-за находки в Ези гипотеза о существовании двух исходных рукописей для поздних копий Тацита подвергается сомнению. Однако неизвестно, является ли находка в Ези той самой рукописью, обнаруженной в Херсфельде около 1425 года и увиденной Дечембрио в 1455 году в Риме.',
#    'qas': [{'id': '202b432c96e23844ddf9a01782c45cabc45f0757',
#      'answers': [{'text': 'Диктиса Критского', 'answer_start': 885}],
#      'question': 'Чьему авторству принадлежит Дневник Троянской войны?'},
#     {'id': '4697d3568799ea9402ca461621eebdb832e760b1',
#      'answers': [{'text': 'издания. Долгое время на основании существования',
#        'answer_start': 403}],
#      'question': 'Как называются две исходных рукописи для малых произведений Тацита? рукопись X и рукопись Y?'},
#     {'id': '4bd2093616804efd2cf8083561ae1b2990e40905',
#      'answers': [{'text': 'в 1902 году', 'answer_start': 673}],
#      'question': 'В каком году в частной библиотеке в Ези был обнаружен манускрипт, получивший обозначение Codex Aesinas (Рукопись Ези)?'},
#     {'id': '26c327b832dcfd36656f11eca47fefdcb2022cbb',
#      'answers': [{'text': 'Энеа Сильвио Пикколомини', 'answer_start': 18}],
#      'question': 'Кто стал папой римским под именем Пия II?'},
#     {'id': '88c90b5bd4bd4e3e5d3be20e1e80a81ee3e50f87',
#      'answers': [{'text': 'копий Диалогов и Агриколы', 'answer_start': 319}],
#      'question': 'Множество рукописных копий каких трудов было сделано в XV веке?'}]},
#   {'context': 'Для центрального банка, придерживающегося инфляционного таргетирования, доверие является критически важным, так как от него зависят текущие инфляционные ожидания и будущая инфляция. Как отмечают экономисты Банка России, повышение уровня понимания и доверия к политике, снижение неопределенности относительно решений центрального банка способствует увеличению действенности денежно-кредитной политики, то есть усилению ее влияния на решения субъектов экономики всех уровней, а, следовательно, на инфляционные ожидания и инфляцию.',
#    'qas': [{'id': 'fcea659505a450059ea9ec3fd5719a6ad404c01d',
#      'answers': [{'text': 'увеличению действенности денежно-кредитной политики',
#        'answer_start': 348}],
#      'question': 'Чему способствует повышение уровня понимания и доверия к политике и снижение неопределенности относительно решений центрального банка?'},
#     {'id': '62bc1599bd3338de71305d167108cb41c58a8d03',
#      'answers': [{'text': 'на решения субъектов экономики всех уровней',
#        'answer_start': 429}],
#      'question': 'На что влияет кредитно-денежная политика?'},
#     {'id': 'e5d54d6a7858c75951c00ebc425820dd2ecbf2bc',
#      'answers': [{'text': 'Для центрального банка', 'answer_start': 0}],
#      'question': 'Для какого банка доверие является важным?'},
#     {'id': '844ed2b51072abe5154958e10f02bc9c9d6ff0c1',
#      'answers': [{'text': 'текущие инфляционные ожидания и будущая инфляция',
#        'answer_start': 132}],
#      'question': 'Почему для центрального банка доверие является очень важным, что от этого зависит?'},
#     {'id': '47d22594d5ca0f243d27abda924790a32bb61ac2',
#      'answers': [{'text': 'инфляционного таргетирования', 'answer_start': 42}],
#      'question': 'Чего придерживается центральный банк?'}]},
#   {'context': 'Впервые искусственный синтез инсулина в начале 1960-х почти одновременно осуществили Панайотис Катсоянис в Питтсбургском университете и Хельмут Зан в РФТИ Ахена. Первый генно-инженерный человеческий инсулин получен в 1978 году Артуром Риггсом и Кэйити Итакурой в НИИ Бекмана при участии Герберта Бойера из Genentech с помощью технологии рекомбинантной ДНК (рДНК), ими же налажены первые коммерческие препараты такого инсулина — НИИ Бекмана в 1980 году и Genentech в 1982 (под брендом Humulin). Рекомбинантный инсулин производят пекарские дрожжи и кишечная палочка.',
#    'qas': [{'id': 'b6e61088e1e4b8232d978169ec4b6c839daa0bb3',
#      'answers': [{'text': 'пекарские дрожжи и кишечная палочка',
#        'answer_start': 528}],
#      'question': 'Какие микроорганизмы производят рекомбинантный инсулин?'},
#     {'id': '07c39534894c2cfc095682af6ae4597d1a4ff286',
#      'answers': [{'text': 'с помощью технологии рекомбинантной ДНК',
#        'answer_start': 316}],
#      'question': 'С помощью какой технологии был получен генно-инженерный человеческий инсулин?'},
#     {'id': 'c55e26d33bedc5943f6174d9103516d4ff05f8ea',
#      'answers': [{'text': 'Первый генно-инженерный человеческий инсулин',
#        'answer_start': 162}],
#      'question': 'Что было получено в 1978 году Артуром Риггсом и Кэйити Итакурой в НИИ Бекмана?'},
#     {'id': 'e9498048c6681ad3e72de009941282d06f1fe391',
#      'answers': [{'text': 'Humulin', 'answer_start': 484}],
#      'question': 'Под каким брендом были налажены выпуски коммерческих препаратов генно-инженерного человеческого инсулина Genentech в 1982?'},
#     {'id': '3f47a3bfea1b910d9d0f6a9ebfa8c48c7da1bdd2',
#      'answers': [{'text': 'в начале 1960-х', 'answer_start': 38}],
#      'question': 'В начале каких годов впервые осуществили искусственный синтез инсулина?'}]},
#   {'context': 'Исторически исследование бета-распада привело к первому физическому свидетельству существования нейтрино. В 1914 году Дж. Чедвик экспериментально показал, что энергии электронов, испускаемых при бета-распаде, имеют непрерывный, а не дискретный спектр. Это находилось в очевидном противоречии с законом сохранения энергии, поскольку получалось, что часть энергии терялась в процессах бета-распада. Вторая проблема заключалась в том, что спин атома азота-14 был равен 1, что противоречило предсказанию Резерфорда — ½. В известном письме, написанном в 1930 году, Вольфганг Паули предположил, что помимо электронов и протонов атомы содержат очень лёгкую нейтральную частицу, которую он назвал нейтроном. Он предположил, что этот нейтрон испускается при бета-распаде и раньше просто не наблюдался. В 1931 году Энрико Ферми переименовал нейтрон Паули в нейтрино, и в 1934 году Ферми опубликовал очень удачную модель бета-распада, в которой участвовали нейтрино.',
#    'qas': [{'id': '949c70fa02f20237b963fcebdc23003705b37de8',
#      'answers': [{'text': 'Вольфганг Паули', 'answer_start': 560}],
#      'question': 'Кто предположил, что помимо электронов и протонов атомы содержат очень лёгкую нейтральную частицу, которую назвал нейтроном?'},
#     {'id': 'e91cffda589dfcabbf89fa26f2d4e864d5ac1270',
#      'answers': [{'text': 'спектр. Это находилось в очевидном противоречии',
#        'answer_start': 244}],
#      'question': 'В чем оказалось противоречие результата эксперимента Джеймса Чедвика закону сохранения энергии?'},
#     {'id': '479303fba7390e6492003cb4e0adc8fda6a9b124',
#      'answers': [{'text': 'исследование бета-распада', 'answer_start': 12}],
#      'question': 'Что привело привело к первому физическому свидетельству существования нейтрино?'},
#     {'id': 'c655c51189b5c4a8765dde88c0e6df157b21b038',
#      'answers': [{'text': 'В 1931 году', 'answer_start': 793}],
#      'question': 'В каком году нейтрон Паули был переименован в нейтрино?'},
#     {'id': '0dc2ad06db919db2bad2183c95cb3b30efd79487',
#      'answers': [{'text': 'В 1931 году Энрико Ферми переименовал нейтрон Паули в нейтрино, и в 1934 году',
#        'answer_start': 793}],
#      'question': 'В каком году Ферми опубликовал очень удачную модель бета-распада, в которой участвовали нейтрино?'},
#     {'id': '5f3e19a5bfff3ddabd92778f970fdc42239dd54e',
#      'answers': [{'text': '½', 'answer_start': 513}],
#      'question': 'В противоречии предположениям Резерфорда, чему оказался равен спин атома азота-14?'},
#     {'id': '15904423732ba322c69ca74f8238e414752c9fa6',
#      'answers': [{'text': 'В 1931 году', 'answer_start': 793}],
#      'question': 'В каком году Энрико Ферми переименовал нейтрон Паули в нейтрино?'},
#     {'id': '8e1b6e17e10621759a97e040c24620ef2d3dbf0c',
#      'answers': [{'text': 'к первому физическому свидетельству существования нейтрино',
#        'answer_start': 46}],
#      'question': 'К чему привело исследование бета-распада?'}]},
#   {'context': 'Первоначально Гермес — фаллическое божество, изображавшееся гермами. Согласно Геродоту, афиняне первыми из эллинов стали делать его изображение с напряженным членом, научившись этому у пеласгов, у которых было священное сказание. Герма представляла собой каменную колонну с вырезанной головой Гермеса и подчёркнутыми половыми органами. Устанавливались гермы на перекрёстках дорог и, наряду с сакральной функцией, служили дорожными указателями. В 415 до н. э. гермы были уничтожены. Во времена Рима они потеряли связь с фаллическим культом Гермеса и стали изготавливаться в виде прямоугольной колонны, на которую водружался бюст человека или божества.',
#    'qas': [{'id': '29438db21f2340dfdec561570784ab2b85892d13',
#      'answers': [{'text': 'каменную колонну', 'answer_start': 255}],
#      'question': 'Что представляла собой Герма?'},
#     {'id': '82c24520c6dfc7a2a6d73c2e978a7af0408f4ef3',
#      'answers': [{'text': 'В 415 до н. э.', 'answer_start': 444}],
#      'question': 'Когда гермы были уничтожены?'},
#     {'id': '3469265cb507629f35eb68e3fd3c31885cf75c4a',
#      'answers': [{'text': 'на перекрёстках дорог', 'answer_start': 358}],
#      'question': 'Где устанавливались гермы?'},
#     {'id': '86989d81b1a65edc1161a653c84bf5903eddfe93',
#      'answers': [{'text': 'фаллическое божество', 'answer_start': 23}],
#      'question': 'Кто такой Гермес?'},
#     {'id': '0c1a242b8c681be70cb7977eaa5382ff3c19a131',
#      'answers': [{'text': 'у пеласгов', 'answer_start': 183}],
#      'question': 'У кого научились афиняне делать изображение Гермеса с напряженным членом?'}]},
#   {'context': 'Аналогичные правила относятся к монтажу кадров с панорамированием и снятых движущейся камерой. Ещё одним требованием монтажа является поддержание ощущения непрерывности действия, не допускающее пропуска его частей. Например, если в предыдущем кадре человек входит в дверь, то в следующем он должен выходить из неё с другой стороны. Если после склейки он окажется уже сидящим на стуле в комнате, в которую вошёл, это нарушит целостность сцены. Для устранения такого логического скачка необходима вклейка между соседними кадрами смысловой перебивки , имеющей отношение к обоим монтируемым кадрам. Такие перебивочные планы специально снимаются операторами кинохроники и телевидения для облегчения работы монтажёров.',
#    'qas': [{'id': 'f5a78e9015ce4d7ca8c87a70e077483afb66dd04',
#      'answers': [{'text': 'поддержание ощущения непрерывности действия',
#        'answer_start': 134}],
#      'question': 'Какое есть необходимое требование к монтажу?'},
#     {'id': 'd3344065912218980399c9ff82e653a5971321c1',
#      'answers': [{'text': 'для облегчения работы монтажёров',
#        'answer_start': 679}],
#      'question': 'Зачем перебивочные планы специально снимаются операторами кинохроники и телевидения?'},
#     {'id': '57bb50e08408747cb44a76aca4ad5c7afa7773fe',
#      'answers': [{'text': 'вклейка между соседними кадрами смысловой перебивки',
#        'answer_start': 495}],
#      'question': 'Что нужно для устранения логического скачка?'},
#     {'id': 'ae97ea840ad6053c2be16e512a6474bf406c0219',
#      'answers': [{'text': 'к монтажу кадров с панорамированием и снятых движущейся камерой',
#        'answer_start': 30}],
#      'question': 'К чему относятся аналогичные правила?'}]},
#   {'context': 'Архитекторами стали Джино Дзаванелла и Элой Суарес, а инженером — Максимум Майовеки. О строительстве было официально объявлено 20 ноября 2008 года в Линготто: всего было отведено 355000 м2 (из которых 45000 предназначены для стадиона, 155000 — для услуг, 34000 — для предпринимательской деятельности и 30000 — для зелёных зон и площадей). Конструкция имеет прямоугольный план, в окружении двух полуэллиптических структур, в которых расположены рестораны и бары. Также есть ложи VIP — спроектированные компанией Pininfarina Extra — с видом прямо на поле.',
#    'qas': [{'id': 'b1aef49385bd6df5478da6f421ca806adc736fbe',
#      'answers': [{'text': '20 ноября 2008 года', 'answer_start': 127}],
#      'question': 'Когда было объявлено о строительстве?'},
#     {'id': 'e1e078009a7c3bf2279d79216bff58842253b3e3',
#      'answers': [{'text': 'Джино Дзаванелла и Элой Суарес',
#        'answer_start': 20}],
#      'question': 'Кто архитекторы стадиона?'},
#     {'id': '5de0653b00cf5e3e2ad4cc512425006b1314d4b3',
#      'answers': [{'text': 'компанией Pininfarina Extra', 'answer_start': 501}],
#      'question': 'Кем спроектированы ложи VIP с видом прямо на поле?'},
#     {'id': 'ee4943fa3b520ae423e724e0bc9510a1befc96ed',
#      'answers': [{'text': 'рестораны и бары', 'answer_start': 444}],
#      'question': 'Что расположено в двух полуэллиптических структурах окружающих основную прямоугольную конструкцию?'},
#     {'id': '25f3eed4826ac30122b46027d946aa2bd62bc6be',
#      'answers': [{'text': '30000', 'answer_start': 302}],
#      'question': 'Какая общая площадь стадиона включая зеленую зону, зону услуг и предпринимательской деятельности?'}]},
#   {'context': 'Составлен Первым Вселенским собором (Никея, Малая Азия) в 325 году (см. Никейский Символ веры); в 381 году расширен и дополнен Вторым Вселенским собором (Константинополь). По названиям мест, где проходили соборы, получил название Никео-Константинопольского или Никео-Цареградского Символа. Никео-Цареградский Символ веры унаследовал основные свои положения из Апостольского Символа веры. Кроме того, в него Первым Вселенским собором добавлены положения из христологии и о Троице, ставящие своей целью отторжение арианства (в частности, отдельным решением Первый Вселенский собор установил, что арианство является ересью).',
#    'qas': [{'id': '63c2f2d58e55802ee1347fb915a45bd0c466f016',
#      'answers': [{'text': 'что арианство является ересью',
#        'answer_start': 590}],
#      'question': 'Что установил Первый Вселенский Собор особым решением?'},
#     {'id': '973aa8ee54ad04cbd3473417738c8fb7542921d9',
#      'answers': [{'text': 'По названиям мест, где проходили соборы',
#        'answer_start': 172}],
#      'question': 'Почему называется Никео-Константинопольским?'},
#     {'id': 'ddfc4153ece74d3e5174a13a0cdf9613a054d31a',
#      'answers': [{'text': 'в 325 году', 'answer_start': 56}],
#      'question': 'Когда составлен Символ веры?'},
#     {'id': 'b499f078d167327c2ee13b63a52bb9d13e779c50',
#      'answers': [{'text': 'отторжение арианства', 'answer_start': 501}],
#      'question': 'Что ставили целью дополнения из христологии и о Троице?'}]},
#   ...]}

# %%
 with open('sub.json',"w", encoding='utf8') as f:
        json.dump(new, f, ensure_ascii=False)

# %% [markdown]
# # Финальный вывод:
#
# Модель RuBERT неплохо справляется с задачами понимания текста в виде ответа на вопрос по содержанию текста без особых усилий по подбору гиперпараметров.
#
# Неплохие результаты модель показала на валидационной выборке F1 = 81% и в соревновании F1 = 84% и занять 3-е место в Leaderboard.
#
# ![image.png](attachment:image.png)
#
# Ссылка на результаты соревнования: https://codalab.lisn.upsaclay.fr/competitions/7335#results
