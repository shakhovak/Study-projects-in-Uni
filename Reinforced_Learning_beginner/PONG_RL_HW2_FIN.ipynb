# %% [markdown]
# <a href="https://colab.research.google.com/github/shakhovak/Study-projects-in-Uni/blob/master/Reinforced_Learning_beginner/PONG_RL_HW2_FIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW 2 Обучение на основе функции полезности
#
# **Задача:** воспроизвести результаты DQN на двух играх Atari.
#
# **Описание.** Ваша задача — воспроизвести результаты DQN на играх Pong и другой игре на ваш выбор из таблицы лекций или семинара. Важно, чтобы вы не выбрали игру, где результат человека значительно превосходит DQN. Учтите, что некоторые игры могут потребовать специфических методов, например, MontezumaRevenge.
#
# Цель состоит в том, чтобы ваш агент достиг среднего вознаграждения, указанного в таблице для DQN, с учетом std dev.
#
# **Детали:**
# - Воспользуйтесь техниками из оригинальной статьи DeepMind: replay buffer, frame skip, target network.
# - Можно использовать любой фреймворк.
# - Приветствуются улучшения базового кода или дополнительные техники.
#
# **Что нужно сдать:**
# - Код обучения в формате Jupyter.
# - График сходимости, показывающий среднее вознаграждение.
# - Веса обученной модели.
# - Код для запуска модели с готовыми весами.
# - Выводы по используемым гиперпараметрам, таким как размер replay buffer, learning rate и т. д.

# %% [markdown]
# # План решения
#
# В этом ноутбуке буду обучать агента играть в игру **Pong**. В решении будет несколько этапов:
#
# 1. Воспользуюсь некоторыми обертками для среды, чтобы можно было перерабатывать данные из среды в формат, приемлимый для нейронной сети. Здксь воспользуюсь стандартым подходом обработки фремов из игры, в точ числе frame skip, когда будет обрабытываться не один фрейм, а стек из 4-х фреймов.
#
# 2. Подготовлю 2 серточных сети, которые будут участвовать в обучении агента.
#
# 3. Буду также использовать буфер опыта (experience buffer)
#
# Этот ноутбук включает как обучение, так и инференс модели уже с загруженными весами модели. Веса модели в этом же репозитории.
#
# Обучение проходило на ВМ Yandex Cloud, используемая конфигруция включает V100. **ДЛя работы в Colab, нужно поменять значок % на ! при загрузке библиотек, в остальном все должно работать!**

# %%
#%apt-get update > /dev/null 2>&1
###!pip install --upgrade setuptools 2>&1
#!pip install ez_setup > /dev/null 2>&1
# %pip install --upgrade gymnasium > /dev/null 2>&1
# %pip install "gymnasium[atari, accept-rom-license]" > /dev/null 2>&1
# %pip install -y swig > /dev/null 2>&1
# %pip install gymnasium[box2d] > /dev/null 2>&1

# %%
# %pip install moviepy --upgrade > /dev/null 2>&1

# %%
import cv2
import copy
import random
import gc
import gymnasium as gym
import numpy as np
import torch
import ipywidgets as widgets
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

from gym import spaces
from tqdm import tqdm
from collections import deque
from IPython import display
from IPython.display import clear_output
from matplotlib import animation
from torchsummary import summary
import warnings
warnings.filterwarnings("ignore")

import argparse
import time
import collections

cv2.ocl.setUseOpenCL(False)
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # Gym Wrappers
#
# Воспользуюсь готовыми wrappers для atari games ([ссылка здесь](https://)(https://github.com/openai/baselines/blob/master/baselines/common/atari_wrappers.py)) для модификации output для среды.
#
# **Wrappers:**
#
# - Обертки для кода OpenAI gym
# - позволяют трансформировать наблюдения из среды для передачи в нейронную сеть и наоборот, из нейронной сети для передачи в среду
#
# В этом решении я использовала следующие обертки:
#
# - **MaxAndSkipEnv** - поволяет собирать в один стек 4 фрейма игры для обучения и принятия решения. В целом значительно ускоряет обучение агента. Для Pong - обязательно.
# - **FireResetEnv** - позволяет автоматически нажимать кнопку удара, если это требуется в игре. Для pong - обязательна
# - **ProcessFrame** - обрабатывает фреймы как картинки: переводит в черно-белый цвет, уменьшает размер для ускорения обучения
# - **BufferWrapper** - отслеживает последние 4 фрейма и приводит их в формат тензора
# - **ImageToPyTorch** - приводит тензоры в формат, необходимый для нейронной сети
#
# Далее соединяем все обертки в один стек, который будет запускаться при перезапуске среды (на команду reset)

# %%
# for the atari games that require fire button
class FireResetEnv(gym.Wrapper):
    def __init__(self, env):
        """Take action on reset for environments that are fixed until firing."""
        super(FireResetEnv, self).__init__(env)
        assert env.unwrapped.get_action_meanings()[1] == 'FIRE'
        assert len(env.unwrapped.get_action_meanings()) >= 3

    def reset(self, **kwargs):
        self.env.reset(**kwargs)
        obs, reward, done, truncated, info = self.env.step(1)
        if done:
            self.env.reset(**kwargs)
        obs, reward, done, truncated, info = self.env.step(2)
        if done:
            self.env.reset(**kwargs)
        return obs, info

    def step(self, action):
        return self.env.step(action)

# to increase the speed of learning by processing every 4th frame and return the frame with highest reward
# frame skipping
class MaxAndSkipEnv(gym.Wrapper):
    def __init__(self, env, skip=4):
        """Return only every `skip`-th frame"""
        super(MaxAndSkipEnv, self).__init__(env)
        # most recent raw observations (for max pooling across time steps)
        self._obs_buffer = collections.deque(maxlen=2)
        self._skip = skip

    def step(self, action):
        """Repeat action, sum reward, and max over last observations."""
        total_reward = 0.0
        done = None
        for i in range(self._skip):
            obs, reward, done, truncated, info = self.env.step(action)
            self._obs_buffer.append(obs)
            total_reward += reward
            if done:
                break
        # Note that the observation on the done=True frame
        # doesn't matter
        max_frame = np.max(np.stack(self._obs_buffer), axis=0)

        return max_frame, total_reward, done, truncated, info

    def reset(self, **kwargs):
        return self.env.reset(**kwargs)

# convert images to black&white and down-size images
class ProcessFrame(gym.ObservationWrapper):
    def __init__(self, env):
      super(ProcessFrame, self).__init__(env)
      self.observation_space = gym.spaces.Box(low=0, high=255, shape=(84, 84, 1), dtype=np.uint8)

    def observation(self, obs):
        return ProcessFrame.process(obs)

    @staticmethod
    def process(frame):
        img = np.reshape(frame, frame.shape).astype(np.float32)
        img = img[:, :, 0] * 0.299 + img[:, :, 1] * 0.587 + img[:, :, 2] * 0.114
        resized_screen = cv2.resize(img, (84, 110), interpolation=cv2.INTER_AREA)
        x_t = resized_screen[18:102, :]
        x_t = np.reshape(x_t, [84, 84, 1])
        return x_t.astype(np.uint8)


# pytorch requires tensors in a form {channel, width, height}, current data is in a form {width, height, channel}
class ImageToPyTorch(gym.ObservationWrapper):
    def __init__(self, env):
      super(ImageToPyTorch, self).__init__(env)
      old_shape = self.observation_space.shape
      self.observation_space = gym.spaces.Box(low=0.0, high=1.0, shape=(old_shape[-1], old_shape[0], old_shape[1]),
                                                dtype=np.float32)
    def observation(self, observation):
        return np.moveaxis(observation, 2, 0)

class BufferWrapper(gym.ObservationWrapper):
    def __init__(self, env, n_steps, dtype=np.float32):
        super(BufferWrapper, self).__init__(env)
        self.dtype = dtype
        old_space = env.observation_space
        self.observation_space = gym.spaces.Box(old_space.low.repeat(n_steps, axis=0),
                                                old_space.high.repeat(n_steps, axis=0), dtype=dtype)

    def reset(self, **kwargs):
        self.buffer = np.zeros_like(self.observation_space.low, dtype=self.dtype)
        obs, info = self.env.reset(**kwargs)
        return self.observation(obs), info

    def observation(self, observation):
      self.buffer[:-1] = self.buffer[1:]
      self.buffer[-1] = observation
      return self.buffer

# normalizes pixels to tensor with values between 0 and 1
class ScaledFloatFrame(gym.ObservationWrapper):
    def observation(self, obs):
        return np.array(obs).astype(np.float32) / 255.0


# generate a stack of wrappers each time env is reset
def make_env(env_name):
    env = gym.make(env_name, render_mode = 'rgb_array')
    env = MaxAndSkipEnv(env)
    env = FireResetEnv(env)
    env = ProcessFrame(env)
    env = ImageToPyTorch(env)
    env = BufferWrapper(env, 4)
    return ScaledFloatFrame(env)

# %% [markdown]
# # Hyperparametres
#
# Добавим гиперпараметры:
# - **MEAN_REWARD_GOAL** - целевая среднее величина за 100 последних эпизода. При достижении этой величины закончится обучение агента. В задании нам предлагают воспользоваться величиной 18,9 (со стандартным отклонением в 1,3). Для того, чтобы этого добиться я буду рассчитывать среднее за 100 эпизодов и выберу величину 19,5. Думаю, таким образом, я смогу добиться нужного результата включая стандратное отклонение.
# - **GAMMA** - фактор дисконтирования для уравнения Белмана, величина от 0 до 1. Чем ближе величина к нулю, тем меньший вес передается текущему вознаграждению, вынуждая агента откладывать вознаграждение на будущее. Для игры в понг, я взяла гамму == **0,99**, так  игра не долгая и нет необходимости придавать бОльший вес отложенным вознаграждениям.
# - **BATCH_SIZE** - величина батча с данными, приходящего в нейронную сеть. Здесь основное ограничение - объем памяти. При обучении на T4 довольно быстро идет обучение с размеров батча == **32**. думаю, такой размер оптимален при выборе между скоростью обучения и его качеством.
# - **REPLAY_BUFFER_SIZE** - максимальная вместимость буфера опыта. БОльшая величина буфера позволяет сохранять разнообразные варианты опыта, уменьшая таким образом потенциальную корреляцию и делая модель более устойчивой на инференсе. При этом слишком большой размер буфера может замедлить обучение. Для игры в Pong проводилось исследование [вот ссылка](https://github.com/rikluost/RL_DQN_Pong) как размер буфера влияет на среднюю величину вознаградения. Как видно из рисунка ниже - 50 тыс. оптимальное. Я решила взять **20 тыс**, так как есть опасения из-за ограничения ресурсов.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **REPLAY_MIN_SIZE** минимальное количество перехов в буфере перед началом обратного распространения ошибки внутри сети. Я выбрала величину равную буферу в **10000**. Каких-то исследований про эту величину я не нашла, воспользовалась примером в нескольких имплементациях.
# - **LEARNING_RATE = 1e-4**. Данную величину чаще всего используют в имплеметациях, получая хорошие результаты именно для игры понг.
# - **SYNC_TARGET_FRAMES = 1000** - как часто веса из основной модели копируются в дублирующую для предсказания следующего состояния
#
# - **EPSILON_START = 1.0** - начальная величина вероятности семплирования рандомного действия.
# - **EPSILON_FINAL = 0.02** - минимальная величина вероятности семплирования рандомного действия
# - **EPSILON_DECAY_FRAMES = 10^5** - количество шагов перехода от начальной величины вероятности к минимальной
#
# Данный подход (часто называют жадной стратегией подбора параметра) позволяет уменьшатиь вероятность семплирования рандомнго действия, так как растет уверенность модели в предсказании (см. рисунок ниже). В большинтсве случаем начинают всегда с максимального значения в 1, когда только рандомное семплирование. Финальное значение 1-2% для вероятности для обеспечения рандомности. Также кол-во шагов часто берут именно 0,0005, так как модель успевает уже неплохо выучится за это время.
#
#
# ![image.png](data:image/png;base64,...)

# %%
DEFAULT_ENV_NAME = "PongNoFrameskip-v4"
MEAN_REWARD_GOAL = 19.0 # when reward for the last 100 episodes exeeds this threshhold the training stops

GAMMA = 0.99 # discount factor
BATCH_SIZE = 32
REPLAY_BUFFER_SIZE = 20000
REPLAY_MIN_SIZE = 10000 # min transitions before back propagation
LEARNING_RATE = 1e-4
SYNC_TARGET_FRAMES = 1000 # how often are weights are copied from main network to target network

EPSILON_START = 1.0
EPSILON_FINAL = 0.02
EPSILON_DECAY_FRAMES = 10**5


Experience = collections.namedtuple('Experience', field_names=['state', 'action', 'reward', 'done', 'new_state'])

# %% [markdown]
# Активируем среду и посмотрим основные параметры:

# %%
env = make_env(DEFAULT_ENV_NAME)
env.reset()
plt.imshow(env.render())

print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))
# Out:
# Action Space Discrete(6)
# State Space Box(0.0, 1.0, (4, 84, 84), float32)

# %% [markdown]
# Для обучения нейронной сети создается буфер для хранения опыта. В него добавляем 2 метода: добавления опыта в буфер (append) и семплирование из буфера (sample)

# %%
# replay buffer
class ExperienceBuffer:
    def __init__(self, capacity):
        self.buffer = collections.deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, state, action, reward, done, new_state):
        state = np.expand_dims(state, 0)
        new_state = np.expand_dims(new_state, 0)
        self.buffer.append([state, action, reward, done, new_state])

    def sample(self, batch_size):
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        states, actions, rewards, dones, next_states = zip(*[self.buffer[idx] for idx in indices])

        return np.concatenate(states), np.array(actions), np.array(rewards, dtype=np.float32), \
               np.array(dones, dtype=np.uint8), np.concatenate(next_states)

# %% [markdown]
# Создаем класс агента, который будет обучаться игре. Основной метод агента - **play step** - здесь как раз используется жадный алгоритм, регулируемый величиной epsilon. Как я писала выше данная величина ответсвенна за рандомное семплирование действия или его получение из нейронное сети.

# %%
class Agent:
    def __init__(self, env, exp_buffer):
        self.env = env
        self.exp_buffer = exp_buffer
        self._reset()

    def _reset(self):
        state, _ = env.reset()
        self.state = state
        self.total_reward = 0.0

    def play_step(self, net, epsilon=0.0, device="cpu"):
        done_reward = None

        if np.random.random() < epsilon:
           action = env.action_space.sample()

        else:

           state_a = np.array([self.state], copy=False)
           state_v = torch.tensor(state_a).to(device)
           q_vals_v = net(state_v)
           _, act_v = torch.max(q_vals_v, dim=1)
           action = int(act_v.item())

        # do step in the environment
        new_state, reward, is_done, _ , _ = self.env.step(action)
        self.total_reward += reward
        new_state = new_state

        state, action, reward, done, new_state = Experience(self.state, action, reward, is_done, new_state)
        self.exp_buffer.append(state, action, reward, done, new_state)
        self.state = new_state
        if is_done:
            done_reward = self.total_reward
            self._reset()
        return done_reward

# %% [markdown]
# ## Функция для расчета loss
# Для расчета loss используется батч из буфера,который подается в основную и вспомогательную сети. Все входящие данные из батча конвертируются в тензоры.
# Текущее состояние подается в основную сеть, следующее состояние во вспомогательную. На основании полученных величин рассчитывается MSELoss. использование done для закончившихся эпизодов позволяет корректно рассчитать ошибку

# %%
def calc_loss(batch_size, net, tgt_net, device="cpu"):
    #states, actions, rewards, dones, next_states = batch
    states, actions, rewards, dones, next_states = buffer.sample(batch_size)

    states_v = torch.tensor(states).to(device)
    next_states_v = torch.tensor(next_states).to(device)
    actions_v = torch.tensor(actions).to(device)
    rewards_v = torch.tensor(rewards).to(device)
    done = torch.FloatTensor(dones).to(device)

    state_action_values = net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1)
    next_state_values = tgt_net(next_states_v).max(1)[0]

    next_state_values = next_state_values.detach()

    expected_state_action_values = GAMMA * next_state_values * (1-done) + rewards_v
    return nn.MSELoss()(state_action_values, expected_state_action_values)

# %%
import os
def mkdir(base, name):
    path = os.path.join(base, name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path

# %%
def plot(frame_idx, rewards, game):
    clear_output(True)
    plt.figure(figsize=(20,5))
    plt.subplot(131)
    plt.title('frame %s. reward: %s' % (frame_idx, np.mean(rewards[-10:])))
    plt.plot(rewards)
    plt.subplot(132)
    plt.imshow(game)
    plt.show()

# %% [markdown]
# # Network architecture
#
# В качестве основной модели буду использовать сверточную сеть, так как обучается агент на основе изображений, в которую включены следующие слои:
#
# - **Input** (== 4 для Pong, так используется стек из 4-х фреймов)
# - **Conv2D-> ReLU (x3)** - 3 слоя свертки
# - **Fully Connected (512)** -> ReLU
# - **Actions** (на выходе нам нужно одно из 5 действий, поэтому выход из сети будет вектор, равный 6)

# %%
class DQN(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(DQN, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten()
        )

        conv_out_size = self._get_conv_out(input_shape)
        self.fc = nn.Sequential(
            nn.Linear(conv_out_size, 512),
            nn.ReLU(),
            nn.Linear(512, n_actions)
        )

    def _get_conv_out(self, shape):
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size()))

    def forward(self, x):
        conv_out = self.conv(x).view(x.size()[0], -1)
        #conv_out = torch.flatten(self.conv(x), start_dim=1 )
        return self.fc(conv_out)

# %%
net = DQN(env.observation_space.shape, env.action_space.n).to(device)
tgt_net = DQN(env.observation_space.shape, env.action_space.n).to(device)

# %%
summary(net, env.observation_space.shape)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 20, 20]           8,224
#               ReLU-2           [-1, 32, 20, 20]               0
#             Conv2d-3             [-1, 64, 9, 9]          32,832
#               ReLU-4             [-1, 64, 9, 9]               0
#             Conv2d-5             [-1, 64, 7, 7]          36,928
#               ReLU-6             [-1, 64, 7, 7]               0
#            Flatten-7                 [-1, 3136]               0
#             Linear-8                  [-1, 512]       1,606,144
#               ReLU-9                  [-1, 512]               0
#            Linear-10                    [-1, 6]           3,078
# ================================================================
# Total params: 1,687,206
# Trainable params: 1,687,206
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 0.35
# Params size (MB): 6.44
# Estimated Total Size (MB): 6.90
# ----------------------------------------------------------------

# %% [markdown]
# # Training
#
# Основной цикл обучения включает инициализацию буфера опыта и агента. Накопленное вознаграждение за игру буду собирать в total_rewards. По каждой игре буду выводить результаты.
# При увеличении средней величины вознаграждения за послдение 100 эпизодов веса модели будут сохраняться в качестве лучшей. Обучение остановится, когда будет достигнут нужный уровень вознаграждения.

# %%
buffer = ExperienceBuffer(REPLAY_BUFFER_SIZE)
agent = Agent(env, buffer)
epsilon = EPSILON_START

optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE)
total_rewards = []
frame_idx = 0
ts_frame = 0
ts = time.time()
best_mean_reward = None

mkdir('.', 'checkpoints')

while True:
        frame_idx += 1
        epsilon = max(EPSILON_FINAL, EPSILON_START - frame_idx / EPSILON_DECAY_FRAMES)

        reward = agent.play_step(net, epsilon, device=device)
        if reward is not None:
            total_rewards.append(reward)
            speed = (frame_idx - ts_frame) / (time.time() - ts)
            ts_frame = frame_idx
            ts = time.time()
            mean_reward = np.mean(total_rewards[-100:])
            print("%d: done %d games, mean reward %.3f, eps %.2f, speed %.2f f/s" % (
                frame_idx, len(total_rewards), mean_reward, epsilon,
                speed
            ))

            if best_mean_reward is None or best_mean_reward < mean_reward:
                torch.save(net.state_dict(), './checkpoints/' + DEFAULT_ENV_NAME + "-best.dat")
                if best_mean_reward is not None:
                    print("Best mean reward updated %.3f -> %.3f, model saved" % (best_mean_reward, mean_reward))
                best_mean_reward = mean_reward
            if mean_reward > MEAN_REWARD_GOAL:
                print("Solved in %d frames!" % frame_idx)
                break

        if len(buffer) < REPLAY_MIN_SIZE:
            continue

        if frame_idx % SYNC_TARGET_FRAMES == 0:
            tgt_net.load_state_dict(net.state_dict())

        optimizer.zero_grad()
        #batch = buffer.sample(BATCH_SIZE)
        loss_t = calc_loss(BATCH_SIZE, net, tgt_net, device=device)
        loss_t.backward()
        optimizer.step()
# Out:
# 791: done 1 games, mean reward -21.000, eps 0.99, speed 539.59 f/s
# 1669: done 2 games, mean reward -21.000, eps 0.98, speed 569.70 f/s
# 2640: done 3 games, mean reward -21.000, eps 0.97, speed 581.13 f/s
# 3481: done 4 games, mean reward -21.000, eps 0.97, speed 586.70 f/s
# 4303: done 5 games, mean reward -21.000, eps 0.96, speed 582.78 f/s
# 5065: done 6 games, mean reward -21.000, eps 0.95, speed 583.94 f/s
# 6113: done 7 games, mean reward -20.714, eps 0.94, speed 571.84 f/s
# Best mean reward updated -21.000 -> -20.714, model saved
# 6935: done 8 games, mean reward -20.750, eps 0.93, speed 562.45 f/s
# 7842: done 9 games, mean reward -20.778, eps 0.92, speed 578.96 f/s
# 8750: done 10 games, mean reward -20.800, eps 0.91, speed 569.80 f/s
# 9679: done 11 games, mean reward -20.727, eps 0.90, speed 572.52 f/s
# 10716: done 12 games, mean reward -20.667, eps 0.89, speed 134.42 f/s
# Best mean reward updated -20.714 -> -20.667, model saved
# 11538: done 13 games, mean reward -20.692, eps 0.88, speed 107.40 f/s
# 12360: done 14 games, mean reward -20.714, eps 0.88, speed 110.15 f/s
# 13295: done 15 games, mean reward -20.667, eps 0.87, speed 109.50 f/s
# 14103: done 16 games, mean reward -20.688, eps 0.86, speed 106.21 f/s
# 14946: done 17 games, mean reward -20.706, eps 0.85, speed 105.46 f/s
# 15865: done 18 games, mean reward -20.611, eps 0.84, speed 104.95 f/s
# Best mean reward updated -20.667 -> -20.611, model saved
# 16687: done 19 games, mean reward -20.632, eps 0.83, speed 105.22 f/s
# 17507: done 20 games, mean reward -20.650, eps 0.82, speed 104.75 f/s
# 18489: done 21 games, mean reward -20.619, eps 0.82, speed 103.53 f/s
# 19491: done 22 games, mean reward -20.591, eps 0.81, speed 105.20 f/s
# Best mean reward updated -20.611 -> -20.591, model saved
# 20300: done 23 games, mean reward -20.609, eps 0.80, speed 106.93 f/s
# 21327: done 24 games, mean reward -20.625, eps 0.79, speed 113.93 f/s
# 22246: done 25 games, mean reward -20.600, eps 0.78, speed 116.25 f/s
# 23098: done 26 games, mean reward -20.615, eps 0.77, speed 113.38 f/s
# 23916: done 27 games, mean reward -20.630, eps 0.76, speed 116.45 f/s
# 24868: done 28 games, mean reward -20.643, eps 0.75, speed 114.73 f/s
# 25736: done 29 games, mean reward -20.621, eps 0.74, speed 117.50 f/s
# 26596: done 30 games, mean reward -20.600, eps 0.73, speed 116.13 f/s
# 27616: done 31 games, mean reward -20.548, eps 0.72, speed 115.85 f/s
# Best mean reward updated -20.591 -> -20.548, model saved
# 28589: done 32 games, mean reward -20.531, eps 0.71, speed 113.23 f/s
# Best mean reward updated -20.548 -> -20.531, model saved
# 29578: done 33 games, mean reward -20.515, eps 0.70, speed 114.44 f/s
# Best mean reward updated -20.531 -> -20.515, model saved
# 30475: done 34 games, mean reward -20.500, eps 0.70, speed 115.00 f/s
# Best mean reward updated -20.515 -> -20.500, model saved
# 31452: done 35 games, mean reward -20.486, eps 0.69, speed 112.62 f/s
# Best mean reward updated -20.500 -> -20.486, model saved
# 32621: done 36 games, mean reward -20.472, eps 0.67, speed 114.50 f/s
# Best mean reward updated -20.486 -> -20.472, model saved
# 33501: done 37 games, mean reward -20.486, eps 0.66, speed 113.78 f/s
# 34291: done 38 games, mean reward -20.500, eps 0.66, speed 115.84 f/s
# 35113: done 39 games, mean reward -20.513, eps 0.65, speed 111.81 f/s
# 36048: done 40 games, mean reward -20.500, eps 0.64, speed 113.46 f/s
# 37422: done 41 games, mean reward -20.390, eps 0.63, speed 113.65 f/s
# Best mean reward updated -20.472 -> -20.390, model saved
# 38328: done 42 games, mean reward -20.405, eps 0.62, speed 111.80 f/s
# 39523: done 43 games, mean reward -20.372, eps 0.60, speed 114.92 f/s
# Best mean reward updated -20.390 -> -20.372, model saved
# 40723: done 44 games, mean reward -20.295, eps 0.59, speed 114.06 f/s
# Best mean reward updated -20.372 -> -20.295, model saved
# 41619: done 45 games, mean reward -20.311, eps 0.58, speed 109.56 f/s
# 42914: done 46 games, mean reward -20.261, eps 0.57, speed 110.34 f/s
# Best mean reward updated -20.295 -> -20.261, model saved
# 44058: done 47 games, mean reward -20.234, eps 0.56, speed 111.06 f/s
# Best mean reward updated -20.261 -> -20.234, model saved
# 45029: done 48 games, mean reward -20.250, eps 0.55, speed 108.36 f/s
# 46161: done 49 games, mean reward -20.245, eps 0.54, speed 114.25 f/s
# 47421: done 50 games, mean reward -20.240, eps 0.53, speed 112.81 f/s
# 48665: done 51 games, mean reward -20.196, eps 0.51, speed 111.86 f/s
# Best mean reward updated -20.234 -> -20.196, model saved
# 50028: done 52 games, mean reward -20.154, eps 0.50, speed 111.87 f/s
# Best mean reward updated -20.196 -> -20.154, model saved
# 51146: done 53 games, mean reward -20.151, eps 0.49, speed 110.69 f/s
# Best mean reward updated -20.154 -> -20.151, model saved
# 52734: done 54 games, mean reward -20.130, eps 0.47, speed 108.85 f/s
# Best mean reward updated -20.151 -> -20.130, model saved
# 53993: done 55 games, mean reward -20.109, eps 0.46, speed 111.69 f/s
# Best mean reward updated -20.130 -> -20.109, model saved
# 55077: done 56 games, mean reward -20.125, eps 0.45, speed 108.97 f/s
# 56549: done 57 games, mean reward -20.053, eps 0.43, speed 109.87 f/s
# Best mean reward updated -20.109 -> -20.053, model saved
# 57706: done 58 games, mean reward -20.069, eps 0.42, speed 110.06 f/s
# 59052: done 59 games, mean reward -20.017, eps 0.41, speed 109.78 f/s
# Best mean reward updated -20.053 -> -20.017, model saved
# 60269: done 60 games, mean reward -20.017, eps 0.40, speed 109.62 f/s
# Best mean reward updated -20.017 -> -20.017, model saved
# 61895: done 61 games, mean reward -20.000, eps 0.38, speed 109.12 f/s
# Best mean reward updated -20.017 -> -20.000, model saved
# 63492: done 62 games, mean reward -19.984, eps 0.37, speed 108.90 f/s
# Best mean reward updated -20.000 -> -19.984, model saved
# 65062: done 63 games, mean reward -19.937, eps 0.35, speed 101.87 f/s
# Best mean reward updated -19.984 -> -19.937, model saved
# 66678: done 64 games, mean reward -19.906, eps 0.33, speed 109.86 f/s
# Best mean reward updated -19.937 -> -19.906, model saved
# 68354: done 65 games, mean reward -19.877, eps 0.32, speed 107.78 f/s
# Best mean reward updated -19.906 -> -19.877, model saved
# 70305: done 66 games, mean reward -19.833, eps 0.30, speed 99.46 f/s
# Best mean reward updated -19.877 -> -19.833, model saved
# 72011: done 67 games, mean reward -19.791, eps 0.28, speed 108.40 f/s
# Best mean reward updated -19.833 -> -19.791, model saved
# 73556: done 68 games, mean reward -19.765, eps 0.26, speed 108.95 f/s
# Best mean reward updated -19.791 -> -19.765, model saved
# 75125: done 69 games, mean reward -19.725, eps 0.25, speed 107.62 f/s
# Best mean reward updated -19.765 -> -19.725, model saved
# 76992: done 70 games, mean reward -19.614, eps 0.23, speed 107.17 f/s
# Best mean reward updated -19.725 -> -19.614, model saved
# 78851: done 71 games, mean reward -19.592, eps 0.21, speed 108.82 f/s
# Best mean reward updated -19.614 -> -19.592, model saved
# 80861: done 72 games, mean reward -19.528, eps 0.19, speed 103.77 f/s
# Best mean reward updated -19.592 -> -19.528, model saved
# 82842: done 73 games, mean reward -19.479, eps 0.17, speed 105.77 f/s
# Best mean reward updated -19.528 -> -19.479, model saved
# 84844: done 74 games, mean reward -19.486, eps 0.15, speed 106.68 f/s
# 86943: done 75 games, mean reward -19.453, eps 0.13, speed 106.49 f/s
# Best mean reward updated -19.479 -> -19.453, model saved
# 88859: done 76 games, mean reward -19.408, eps 0.11, speed 105.36 f/s
# Best mean reward updated -19.453 -> -19.408, model saved
# 90654: done 77 games, mean reward -19.377, eps 0.09, speed 105.53 f/s
# Best mean reward updated -19.408 -> -19.377, model saved
# 93930: done 78 games, mean reward -19.231, eps 0.06, speed 106.30 f/s
# Best mean reward updated -19.377 -> -19.231, model saved
# 96065: done 79 games, mean reward -19.203, eps 0.04, speed 101.60 f/s
# Best mean reward updated -19.231 -> -19.203, model saved
# 98494: done 80 games, mean reward -19.125, eps 0.02, speed 107.66 f/s
# Best mean reward updated -19.203 -> -19.125, model saved
# 100446: done 81 games, mean reward -19.099, eps 0.02, speed 107.34 f/s
# Best mean reward updated -19.125 -> -19.099, model saved
# 103136: done 82 games, mean reward -19.037, eps 0.02, speed 106.86 f/s
# Best mean reward updated -19.099 -> -19.037, model saved
# 106223: done 83 games, mean reward -18.892, eps 0.02, speed 108.51 f/s
# Best mean reward updated -19.037 -> -18.892, model saved
# 108827: done 84 games, mean reward -18.845, eps 0.02, speed 107.71 f/s
# Best mean reward updated -18.892 -> -18.845, model saved
# 112307: done 85 games, mean reward -18.729, eps 0.02, speed 108.40 f/s
# Best mean reward updated -18.845 -> -18.729, model saved
# 115171: done 86 games, mean reward -18.674, eps 0.02, speed 107.15 f/s
# Best mean reward updated -18.729 -> -18.674, model saved
# 117850: done 87 games, mean reward -18.621, eps 0.02, speed 108.48 f/s
# Best mean reward updated -18.674 -> -18.621, model saved
# 121786: done 88 games, mean reward -18.500, eps 0.02, speed 107.76 f/s
# Best mean reward updated -18.621 -> -18.500, model saved
# 124412: done 89 games, mean reward -18.438, eps 0.02, speed 108.82 f/s
# Best mean reward updated -18.500 -> -18.438, model saved
# 127284: done 90 games, mean reward -18.322, eps 0.02, speed 108.27 f/s
# Best mean reward updated -18.438 -> -18.322, model saved
# 130063: done 91 games, mean reward -18.264, eps 0.02, speed 108.99 f/s
# Best mean reward updated -18.322 -> -18.264, model saved
# 133620: done 92 games, mean reward -18.098, eps 0.02, speed 108.26 f/s
# Best mean reward updated -18.264 -> -18.098, model saved
# 136329: done 93 games, mean reward -18.022, eps 0.02, speed 108.40 f/s
# Best mean reward updated -18.098 -> -18.022, model saved
# 139401: done 94 games, mean reward -17.926, eps 0.02, speed 109.14 f/s
# Best mean reward updated -18.022 -> -17.926, model saved
# 143162: done 95 games, mean reward -17.842, eps 0.02, speed 108.30 f/s
# Best mean reward updated -17.926 -> -17.842, model saved
# 145771: done 96 games, mean reward -17.802, eps 0.02, speed 107.92 f/s
# Best mean reward updated -17.842 -> -17.802, model saved
# 149148: done 97 games, mean reward -17.711, eps 0.02, speed 108.64 f/s
# Best mean reward updated -17.802 -> -17.711, model saved
# 152950: done 98 games, mean reward -17.561, eps 0.02, speed 108.19 f/s
# Best mean reward updated -17.711 -> -17.561, model saved
# 156925: done 99 games, mean reward -17.394, eps 0.02, speed 107.93 f/s
# Best mean reward updated -17.561 -> -17.394, model saved
# 160959: done 100 games, mean reward -17.290, eps 0.02, speed 107.38 f/s
# Best mean reward updated -17.394 -> -17.290, model saved
# 163547: done 101 games, mean reward -17.220, eps 0.02, speed 106.04 f/s
# Best mean reward updated -17.290 -> -17.220, model saved
# 166754: done 102 games, mean reward -17.080, eps 0.02, speed 105.94 f/s
# Best mean reward updated -17.220 -> -17.080, model saved
# 170094: done 103 games, mean reward -16.940, eps 0.02, speed 106.90 f/s
# Best mean reward updated -17.080 -> -16.940, model saved
# 174757: done 104 games, mean reward -16.780, eps 0.02, speed 106.56 f/s
# Best mean reward updated -16.940 -> -16.780, model saved
# 178824: done 105 games, mean reward -16.580, eps 0.02, speed 107.73 f/s
# Best mean reward updated -16.780 -> -16.580, model saved
# 182459: done 106 games, mean reward -16.350, eps 0.02, speed 107.20 f/s
# Best mean reward updated -16.580 -> -16.350, model saved
# 186209: done 107 games, mean reward -16.230, eps 0.02, speed 106.98 f/s
# Best mean reward updated -16.350 -> -16.230, model saved
# 188890: done 108 games, mean reward -16.130, eps 0.02, speed 108.31 f/s
# Best mean reward updated -16.230 -> -16.130, model saved
# 191675: done 109 games, mean reward -16.040, eps 0.02, speed 106.42 f/s
# Best mean reward updated -16.130 -> -16.040, model saved
# 195721: done 110 games, mean reward -15.880, eps 0.02, speed 107.24 f/s
# Best mean reward updated -16.040 -> -15.880, model saved
# 199479: done 111 games, mean reward -15.730, eps 0.02, speed 105.32 f/s
# Best mean reward updated -15.880 -> -15.730, model saved
# 203039: done 112 games, mean reward -15.590, eps 0.02, speed 106.77 f/s
# Best mean reward updated -15.730 -> -15.590, model saved
# 206183: done 113 games, mean reward -15.300, eps 0.02, speed 106.28 f/s
# Best mean reward updated -15.590 -> -15.300, model saved
# 210867: done 114 games, mean reward -15.130, eps 0.02, speed 106.58 f/s
# Best mean reward updated -15.300 -> -15.130, model saved
# 214968: done 115 games, mean reward -14.940, eps 0.02, speed 108.01 f/s
# Best mean reward updated -15.130 -> -14.940, model saved
# 219825: done 116 games, mean reward -14.740, eps 0.02, speed 106.91 f/s
# Best mean reward updated -14.940 -> -14.740, model saved
# 223274: done 117 games, mean reward -14.430, eps 0.02, speed 106.67 f/s
# Best mean reward updated -14.740 -> -14.430, model saved
# 227033: done 118 games, mean reward -14.270, eps 0.02, speed 107.02 f/s
# Best mean reward updated -14.430 -> -14.270, model saved
# 230870: done 119 games, mean reward -14.020, eps 0.02, speed 106.84 f/s
# Best mean reward updated -14.270 -> -14.020, model saved
# 234683: done 120 games, mean reward -13.760, eps 0.02, speed 106.60 f/s
# Best mean reward updated -14.020 -> -13.760, model saved
# 238151: done 121 games, mean reward -13.540, eps 0.02, speed 106.27 f/s
# Best mean reward updated -13.760 -> -13.540, model saved
# 241655: done 122 games, mean reward -13.280, eps 0.02, speed 106.81 f/s
# Best mean reward updated -13.540 -> -13.280, model saved
# 245328: done 123 games, mean reward -13.030, eps 0.02, speed 106.82 f/s
# Best mean reward updated -13.280 -> -13.030, model saved
# 249523: done 124 games, mean reward -12.810, eps 0.02, speed 106.30 f/s
# Best mean reward updated -13.030 -> -12.810, model saved
# 253228: done 125 games, mean reward -12.570, eps 0.02, speed 106.82 f/s
# Best mean reward updated -12.810 -> -12.570, model saved
# 257040: done 126 games, mean reward -12.380, eps 0.02, speed 106.99 f/s
# Best mean reward updated -12.570 -> -12.380, model saved
# 259996: done 127 games, mean reward -12.080, eps 0.02, speed 106.46 f/s
# Best mean reward updated -12.380 -> -12.080, model saved
# 262879: done 128 games, mean reward -11.730, eps 0.02, speed 106.69 f/s
# Best mean reward updated -12.080 -> -11.730, model saved
# 265800: done 129 games, mean reward -11.430, eps 0.02, speed 107.67 f/s
# Best mean reward updated -11.730 -> -11.430, model saved
# 268778: done 130 games, mean reward -11.160, eps 0.02, speed 106.82 f/s
# Best mean reward updated -11.430 -> -11.160, model saved
# 271809: done 131 games, mean reward -10.890, eps 0.02, speed 107.15 f/s
# Best mean reward updated -11.160 -> -10.890, model saved
# 274943: done 132 games, mean reward -10.640, eps 0.02, speed 106.15 f/s
# Best mean reward updated -10.890 -> -10.640, model saved
# 277502: done 133 games, mean reward -10.300, eps 0.02, speed 108.02 f/s
# Best mean reward updated -10.640 -> -10.300, model saved
# 279999: done 134 games, mean reward -10.000, eps 0.02, speed 107.83 f/s
# Best mean reward updated -10.300 -> -10.000, model saved
# 282478: done 135 games, mean reward -9.700, eps 0.02, speed 106.99 f/s
# Best mean reward updated -10.000 -> -9.700, model saved
# 285506: done 136 games, mean reward -9.400, eps 0.02, speed 106.71 f/s
# Best mean reward updated -9.700 -> -9.400, model saved
# 288676: done 137 games, mean reward -9.110, eps 0.02, speed 105.52 f/s
# Best mean reward updated -9.400 -> -9.110, model saved
# 291852: done 138 games, mean reward -8.810, eps 0.02, speed 104.99 f/s
# Best mean reward updated -9.110 -> -8.810, model saved
# 294559: done 139 games, mean reward -8.480, eps 0.02, speed 106.74 f/s
# Best mean reward updated -8.810 -> -8.480, model saved
# 297131: done 140 games, mean reward -8.130, eps 0.02, speed 107.32 f/s
# Best mean reward updated -8.480 -> -8.130, model saved
# 299926: done 141 games, mean reward -7.840, eps 0.02, speed 106.39 f/s
# Best mean reward updated -8.130 -> -7.840, model saved
# 302467: done 142 games, mean reward -7.510, eps 0.02, speed 106.71 f/s
# Best mean reward updated -7.840 -> -7.510, model saved
# 305309: done 143 games, mean reward -7.260, eps 0.02, speed 106.82 f/s
# Best mean reward updated -7.510 -> -7.260, model saved
# 307548: done 144 games, mean reward -6.910, eps 0.02, speed 104.99 f/s
# Best mean reward updated -7.260 -> -6.910, model saved
# 309949: done 145 games, mean reward -6.570, eps 0.02, speed 106.05 f/s
# Best mean reward updated -6.910 -> -6.570, model saved
# 312838: done 146 games, mean reward -6.280, eps 0.02, speed 109.41 f/s
# Best mean reward updated -6.570 -> -6.280, model saved
# 315602: done 147 games, mean reward -5.950, eps 0.02, speed 107.99 f/s
# Best mean reward updated -6.280 -> -5.950, model saved
# 318625: done 148 games, mean reward -5.660, eps 0.02, speed 109.19 f/s
# Best mean reward updated -5.950 -> -5.660, model saved
# 321470: done 149 games, mean reward -5.370, eps 0.02, speed 108.41 f/s
# Best mean reward updated -5.660 -> -5.370, model saved
# 324207: done 150 games, mean reward -5.030, eps 0.02, speed 109.12 f/s
# Best mean reward updated -5.370 -> -5.030, model saved
# 326529: done 151 games, mean reward -4.720, eps 0.02, speed 107.35 f/s
# Best mean reward updated -5.030 -> -4.720, model saved
# 328995: done 152 games, mean reward -4.440, eps 0.02, speed 108.59 f/s
# Best mean reward updated -4.720 -> -4.440, model saved
# 331989: done 153 games, mean reward -4.110, eps 0.02, speed 109.52 f/s
# Best mean reward updated -4.440 -> -4.110, model saved
# 334597: done 154 games, mean reward -3.770, eps 0.02, speed 107.55 f/s
# Best mean reward updated -4.110 -> -3.770, model saved
# 336784: done 155 games, mean reward -3.410, eps 0.02, speed 109.98 f/s
# Best mean reward updated -3.770 -> -3.410, model saved
# 339241: done 156 games, mean reward -3.070, eps 0.02, speed 107.67 f/s
# Best mean reward updated -3.410 -> -3.070, model saved
# 341234: done 157 games, mean reward -2.730, eps 0.02, speed 108.75 f/s
# Best mean reward updated -3.070 -> -2.730, model saved
# 343122: done 158 games, mean reward -2.330, eps 0.02, speed 110.75 f/s
# Best mean reward updated -2.730 -> -2.330, model saved
# 345167: done 159 games, mean reward -1.990, eps 0.02, speed 109.28 f/s
# Best mean reward updated -2.330 -> -1.990, model saved
# 346870: done 160 games, mean reward -1.590, eps 0.02, speed 108.74 f/s
# Best mean reward updated -1.990 -> -1.590, model saved
# 348948: done 161 games, mean reward -1.220, eps 0.02, speed 109.19 f/s
# Best mean reward updated -1.590 -> -1.220, model saved
# 350640: done 162 games, mean reward -0.820, eps 0.02, speed 110.10 f/s
# Best mean reward updated -1.220 -> -0.820, model saved
# 352956: done 163 games, mean reward -0.520, eps 0.02, speed 108.26 f/s
# Best mean reward updated -0.820 -> -0.520, model saved
# 355108: done 164 games, mean reward -0.200, eps 0.02, speed 108.09 f/s
# Best mean reward updated -0.520 -> -0.200, model saved
# 357017: done 165 games, mean reward 0.140, eps 0.02, speed 109.04 f/s
# Best mean reward updated -0.200 -> 0.140, model saved
# 358801: done 166 games, mean reward 0.500, eps 0.02, speed 107.88 f/s
# Best mean reward updated 0.140 -> 0.500, model saved
# 360952: done 167 games, mean reward 0.800, eps 0.02, speed 109.01 f/s
# Best mean reward updated 0.500 -> 0.800, model saved
# 363399: done 168 games, mean reward 1.060, eps 0.02, speed 109.11 f/s
# Best mean reward updated 0.800 -> 1.060, model saved
# 365243: done 169 games, mean reward 1.400, eps 0.02, speed 107.81 f/s
# Best mean reward updated 1.060 -> 1.400, model saved
# 366981: done 170 games, mean reward 1.720, eps 0.02, speed 108.99 f/s
# Best mean reward updated 1.400 -> 1.720, model saved
# 369538: done 171 games, mean reward 2.010, eps 0.02, speed 109.05 f/s
# Best mean reward updated 1.720 -> 2.010, model saved
# 371325: done 172 games, mean reward 2.360, eps 0.02, speed 108.02 f/s
# Best mean reward updated 2.010 -> 2.360, model saved
# 373266: done 173 games, mean reward 2.690, eps 0.02, speed 107.00 f/s
# Best mean reward updated 2.360 -> 2.690, model saved
# 375311: done 174 games, mean reward 3.070, eps 0.02, speed 108.94 f/s
# Best mean reward updated 2.690 -> 3.070, model saved
# 378275: done 175 games, mean reward 3.320, eps 0.02, speed 108.17 f/s
# Best mean reward updated 3.070 -> 3.320, model saved
# 380388: done 176 games, mean reward 3.640, eps 0.02, speed 108.43 f/s
# Best mean reward updated 3.320 -> 3.640, model saved
# 382099: done 177 games, mean reward 4.010, eps 0.02, speed 110.17 f/s
# Best mean reward updated 3.640 -> 4.010, model saved
# 384538: done 178 games, mean reward 4.250, eps 0.02, speed 109.90 f/s
# Best mean reward updated 4.010 -> 4.250, model saved
# 386650: done 179 games, mean reward 4.580, eps 0.02, speed 108.26 f/s
# Best mean reward updated 4.250 -> 4.580, model saved
# 388376: done 180 games, mean reward 4.910, eps 0.02, speed 108.10 f/s
# Best mean reward updated 4.580 -> 4.910, model saved
# 390784: done 181 games, mean reward 5.220, eps 0.02, speed 107.30 f/s
# Best mean reward updated 4.910 -> 5.220, model saved
# 393946: done 182 games, mean reward 5.440, eps 0.02, speed 108.40 f/s
# Best mean reward updated 5.220 -> 5.440, model saved
# 396775: done 183 games, mean reward 5.640, eps 0.02, speed 108.79 f/s
# Best mean reward updated 5.440 -> 5.640, model saved
# 398625: done 184 games, mean reward 5.980, eps 0.02, speed 108.20 f/s
# Best mean reward updated 5.640 -> 5.980, model saved
# 400316: done 185 games, mean reward 6.270, eps 0.02, speed 100.98 f/s
# Best mean reward updated 5.980 -> 6.270, model saved
# 402224: done 186 games, mean reward 6.600, eps 0.02, speed 109.61 f/s
# Best mean reward updated 6.270 -> 6.600, model saved
# 404042: done 187 games, mean reward 6.920, eps 0.02, speed 106.83 f/s
# Best mean reward updated 6.600 -> 6.920, model saved
# 406352: done 188 games, mean reward 7.140, eps 0.02, speed 108.60 f/s
# Best mean reward updated 6.920 -> 7.140, model saved
# 408241: done 189 games, mean reward 7.440, eps 0.02, speed 109.11 f/s
# Best mean reward updated 7.140 -> 7.440, model saved
# 410529: done 190 games, mean reward 7.670, eps 0.02, speed 109.21 f/s
# Best mean reward updated 7.440 -> 7.670, model saved
# 412884: done 191 games, mean reward 7.950, eps 0.02, speed 108.22 f/s
# Best mean reward updated 7.670 -> 7.950, model saved
# 414926: done 192 games, mean reward 8.150, eps 0.02, speed 109.66 f/s
# Best mean reward updated 7.950 -> 8.150, model saved
# 417717: done 193 games, mean reward 8.370, eps 0.02, speed 107.69 f/s
# Best mean reward updated 8.150 -> 8.370, model saved
# 419604: done 194 games, mean reward 8.630, eps 0.02, speed 107.54 f/s
# Best mean reward updated 8.370 -> 8.630, model saved
# 421644: done 195 games, mean reward 8.880, eps 0.02, speed 110.45 f/s
# Best mean reward updated 8.630 -> 8.880, model saved
# 424303: done 196 games, mean reward 9.140, eps 0.02, speed 108.23 f/s
# Best mean reward updated 8.880 -> 9.140, model saved
# 426345: done 197 games, mean reward 9.390, eps 0.02, speed 108.56 f/s
# Best mean reward updated 9.140 -> 9.390, model saved
# 428169: done 198 games, mean reward 9.610, eps 0.02, speed 109.51 f/s
# Best mean reward updated 9.390 -> 9.610, model saved
# 430049: done 199 games, mean reward 9.820, eps 0.02, speed 108.59 f/s
# Best mean reward updated 9.610 -> 9.820, model saved
# 432567: done 200 games, mean reward 10.000, eps 0.02, speed 108.39 f/s
# Best mean reward updated 9.820 -> 10.000, model saved
# 434326: done 201 games, mean reward 10.340, eps 0.02, speed 110.16 f/s
# Best mean reward updated 10.000 -> 10.340, model saved
# 436207: done 202 games, mean reward 10.590, eps 0.02, speed 108.50 f/s
# Best mean reward updated 10.340 -> 10.590, model saved
# 437840: done 203 games, mean reward 10.870, eps 0.02, speed 108.02 f/s
# Best mean reward updated 10.590 -> 10.870, model saved
# 439828: done 204 games, mean reward 11.090, eps 0.02, speed 109.47 f/s
# Best mean reward updated 10.870 -> 11.090, model saved
# 441571: done 205 games, mean reward 11.300, eps 0.02, speed 110.73 f/s
# Best mean reward updated 11.090 -> 11.300, model saved
# 443542: done 206 games, mean reward 11.430, eps 0.02, speed 107.71 f/s
# Best mean reward updated 11.300 -> 11.430, model saved
# 445505: done 207 games, mean reward 11.690, eps 0.02, speed 108.42 f/s
# Best mean reward updated 11.430 -> 11.690, model saved
# 447230: done 208 games, mean reward 12.000, eps 0.02, speed 109.82 f/s
# Best mean reward updated 11.690 -> 12.000, model saved
# 449032: done 209 games, mean reward 12.320, eps 0.02, speed 107.83 f/s
# Best mean reward updated 12.000 -> 12.320, model saved
# 450699: done 210 games, mean reward 12.580, eps 0.02, speed 107.74 f/s
# Best mean reward updated 12.320 -> 12.580, model saved
# 452490: done 211 games, mean reward 12.820, eps 0.02, speed 107.08 f/s
# Best mean reward updated 12.580 -> 12.820, model saved
# 454237: done 212 games, mean reward 13.070, eps 0.02, speed 108.25 f/s
# Best mean reward updated 12.820 -> 13.070, model saved
# 456866: done 213 games, mean reward 13.100, eps 0.02, speed 108.47 f/s
# Best mean reward updated 13.070 -> 13.100, model saved
# 458864: done 214 games, mean reward 13.310, eps 0.02, speed 109.13 f/s
# Best mean reward updated 13.100 -> 13.310, model saved
# 460866: done 215 games, mean reward 13.500, eps 0.02, speed 110.33 f/s
# Best mean reward updated 13.310 -> 13.500, model saved
# 462499: done 216 games, mean reward 13.720, eps 0.02, speed 109.18 f/s
# Best mean reward updated 13.500 -> 13.720, model saved
# 464161: done 217 games, mean reward 13.820, eps 0.02, speed 107.96 f/s
# Best mean reward updated 13.720 -> 13.820, model saved
# 465795: done 218 games, mean reward 14.060, eps 0.02, speed 109.25 f/s
# Best mean reward updated 13.820 -> 14.060, model saved
# 467600: done 219 games, mean reward 14.200, eps 0.02, speed 110.13 f/s
# Best mean reward updated 14.060 -> 14.200, model saved
# 469502: done 220 games, mean reward 14.350, eps 0.02, speed 108.15 f/s
# Best mean reward updated 14.200 -> 14.350, model saved
# 471779: done 221 games, mean reward 14.430, eps 0.02, speed 109.64 f/s
# Best mean reward updated 14.350 -> 14.430, model saved
# 473704: done 222 games, mean reward 14.550, eps 0.02, speed 110.47 f/s
# Best mean reward updated 14.430 -> 14.550, model saved
# 476046: done 223 games, mean reward 14.630, eps 0.02, speed 109.50 f/s
# Best mean reward updated 14.550 -> 14.630, model saved
# 478207: done 224 games, mean reward 14.780, eps 0.02, speed 109.23 f/s
# Best mean reward updated 14.630 -> 14.780, model saved
# 479867: done 225 games, mean reward 14.950, eps 0.02, speed 109.86 f/s
# Best mean reward updated 14.780 -> 14.950, model saved
# 481605: done 226 games, mean reward 15.160, eps 0.02, speed 108.64 f/s
# Best mean reward updated 14.950 -> 15.160, model saved
# 483435: done 227 games, mean reward 15.250, eps 0.02, speed 108.58 f/s
# Best mean reward updated 15.160 -> 15.250, model saved
# 485248: done 228 games, mean reward 15.290, eps 0.02, speed 108.51 f/s
# Best mean reward updated 15.250 -> 15.290, model saved
# 487182: done 229 games, mean reward 15.370, eps 0.02, speed 110.56 f/s
# Best mean reward updated 15.290 -> 15.370, model saved
# 489019: done 230 games, mean reward 15.480, eps 0.02, speed 108.05 f/s
# Best mean reward updated 15.370 -> 15.480, model saved
# 491059: done 231 games, mean reward 15.560, eps 0.02, speed 107.77 f/s
# Best mean reward updated 15.480 -> 15.560, model saved
# 493038: done 232 games, mean reward 15.660, eps 0.02, speed 108.59 f/s
# Best mean reward updated 15.560 -> 15.660, model saved
# 495373: done 233 games, mean reward 15.680, eps 0.02, speed 108.24 f/s
# Best mean reward updated 15.660 -> 15.680, model saved
# 497497: done 234 games, mean reward 15.760, eps 0.02, speed 109.18 f/s
# Best mean reward updated 15.680 -> 15.760, model saved
# 499180: done 235 games, mean reward 15.860, eps 0.02, speed 109.06 f/s
# Best mean reward updated 15.760 -> 15.860, model saved
# 500921: done 236 games, mean reward 15.960, eps 0.02, speed 109.07 f/s
# Best mean reward updated 15.860 -> 15.960, model saved
# 502883: done 237 games, mean reward 16.080, eps 0.02, speed 108.44 f/s
# Best mean reward updated 15.960 -> 16.080, model saved
# 504909: done 238 games, mean reward 16.160, eps 0.02, speed 107.90 f/s
# Best mean reward updated 16.080 -> 16.160, model saved
# 506743: done 239 games, mean reward 16.220, eps 0.02, speed 109.49 f/s
# Best mean reward updated 16.160 -> 16.220, model saved
# 508373: done 240 games, mean reward 16.280, eps 0.02, speed 108.01 f/s
# Best mean reward updated 16.220 -> 16.280, model saved
# 510004: done 241 games, mean reward 16.360, eps 0.02, speed 108.25 f/s
# Best mean reward updated 16.280 -> 16.360, model saved
# 511828: done 242 games, mean reward 16.430, eps 0.02, speed 108.39 f/s
# Best mean reward updated 16.360 -> 16.430, model saved
# 513821: done 243 games, mean reward 16.520, eps 0.02, speed 109.19 f/s
# Best mean reward updated 16.430 -> 16.520, model saved
# 515617: done 244 games, mean reward 16.530, eps 0.02, speed 108.30 f/s
# Best mean reward updated 16.520 -> 16.530, model saved
# 517353: done 245 games, mean reward 16.590, eps 0.02, speed 108.24 f/s
# Best mean reward updated 16.530 -> 16.590, model saved
# 519382: done 246 games, mean reward 16.640, eps 0.02, speed 108.86 f/s
# Best mean reward updated 16.590 -> 16.640, model saved
# 521107: done 247 games, mean reward 16.690, eps 0.02, speed 103.20 f/s
# Best mean reward updated 16.640 -> 16.690, model saved
# 522856: done 248 games, mean reward 16.800, eps 0.02, speed 108.22 f/s
# Best mean reward updated 16.690 -> 16.800, model saved
# 524809: done 249 games, mean reward 16.880, eps 0.02, speed 107.32 f/s
# Best mean reward updated 16.800 -> 16.880, model saved
# 526686: done 250 games, mean reward 16.920, eps 0.02, speed 110.57 f/s
# Best mean reward updated 16.880 -> 16.920, model saved
# 528494: done 251 games, mean reward 16.990, eps 0.02, speed 108.03 f/s
# Best mean reward updated 16.920 -> 16.990, model saved
# 530304: done 252 games, mean reward 17.070, eps 0.02, speed 109.77 f/s
# Best mean reward updated 16.990 -> 17.070, model saved
# 532371: done 253 games, mean reward 17.090, eps 0.02, speed 109.17 f/s
# Best mean reward updated 17.070 -> 17.090, model saved
# 534694: done 254 games, mean reward 17.070, eps 0.02, speed 107.73 f/s
# 536581: done 255 games, mean reward 17.100, eps 0.02, speed 109.04 f/s
# Best mean reward updated 17.090 -> 17.100, model saved
# 538451: done 256 games, mean reward 17.140, eps 0.02, speed 107.42 f/s
# Best mean reward updated 17.100 -> 17.140, model saved
# 540111: done 257 games, mean reward 17.160, eps 0.02, speed 108.79 f/s
# Best mean reward updated 17.140 -> 17.160, model saved
# 542149: done 258 games, mean reward 17.140, eps 0.02, speed 107.45 f/s
# 544013: done 259 games, mean reward 17.150, eps 0.02, speed 108.80 f/s
# 545889: done 260 games, mean reward 17.130, eps 0.02, speed 109.70 f/s
# 547519: done 261 games, mean reward 17.160, eps 0.02, speed 107.69 f/s
# 549471: done 262 games, mean reward 17.130, eps 0.02, speed 108.32 f/s
# 551218: done 263 games, mean reward 17.190, eps 0.02, speed 109.03 f/s
# Best mean reward updated 17.160 -> 17.190, model saved
# 553084: done 264 games, mean reward 17.240, eps 0.02, speed 94.66 f/s
# Best mean reward updated 17.190 -> 17.240, model saved
# 554901: done 265 games, mean reward 17.260, eps 0.02, speed 109.48 f/s
# Best mean reward updated 17.240 -> 17.260, model saved
# 556531: done 266 games, mean reward 17.280, eps 0.02, speed 109.44 f/s
# Best mean reward updated 17.260 -> 17.280, model saved
# 558507: done 267 games, mean reward 17.330, eps 0.02, speed 109.99 f/s
# Best mean reward updated 17.280 -> 17.330, model saved
# 560659: done 268 games, mean reward 17.400, eps 0.02, speed 107.76 f/s
# Best mean reward updated 17.330 -> 17.400, model saved
# 562666: done 269 games, mean reward 17.400, eps 0.02, speed 108.77 f/s
# 564588: done 270 games, mean reward 17.370, eps 0.02, speed 111.97 f/s
# 566515: done 271 games, mean reward 17.430, eps 0.02, speed 107.68 f/s
# Best mean reward updated 17.400 -> 17.430, model saved
# 568356: done 272 games, mean reward 17.420, eps 0.02, speed 108.34 f/s
# 570167: done 273 games, mean reward 17.440, eps 0.02, speed 109.11 f/s
# Best mean reward updated 17.430 -> 17.440, model saved
# 571929: done 274 games, mean reward 17.460, eps 0.02, speed 110.88 f/s
# Best mean reward updated 17.440 -> 17.460, model saved
# 573612: done 275 games, mean reward 17.580, eps 0.02, speed 106.76 f/s
# Best mean reward updated 17.460 -> 17.580, model saved
# 575362: done 276 games, mean reward 17.620, eps 0.02, speed 107.95 f/s
# Best mean reward updated 17.580 -> 17.620, model saved
# 577045: done 277 games, mean reward 17.620, eps 0.02, speed 108.70 f/s
# 578742: done 278 games, mean reward 17.660, eps 0.02, speed 108.41 f/s
# Best mean reward updated 17.620 -> 17.660, model saved
# 581138: done 279 games, mean reward 17.590, eps 0.02, speed 107.58 f/s
# 582987: done 280 games, mean reward 17.560, eps 0.02, speed 108.80 f/s
# 585154: done 281 games, mean reward 17.590, eps 0.02, speed 109.73 f/s
# 586784: done 282 games, mean reward 17.720, eps 0.02, speed 107.55 f/s
# Best mean reward updated 17.660 -> 17.720, model saved
# 589365: done 283 games, mean reward 17.720, eps 0.02, speed 108.32 f/s
# 591490: done 284 games, mean reward 17.700, eps 0.02, speed 110.07 f/s
# 593173: done 285 games, mean reward 17.700, eps 0.02, speed 107.59 f/s
# 595801: done 286 games, mean reward 17.660, eps 0.02, speed 109.64 f/s
# 597768: done 287 games, mean reward 17.380, eps 0.02, speed 110.47 f/s
# 599991: done 288 games, mean reward 17.410, eps 0.02, speed 108.92 f/s
# 602485: done 289 games, mean reward 17.380, eps 0.02, speed 109.68 f/s
# 604820: done 290 games, mean reward 17.410, eps 0.02, speed 110.86 f/s
# 606704: done 291 games, mean reward 17.450, eps 0.02, speed 108.52 f/s
# 608600: done 292 games, mean reward 17.460, eps 0.02, speed 108.82 f/s
# 610311: done 293 games, mean reward 17.550, eps 0.02, speed 111.07 f/s
# 611995: done 294 games, mean reward 17.580, eps 0.02, speed 108.02 f/s
# 614144: done 295 games, mean reward 17.600, eps 0.02, speed 108.26 f/s
# 615917: done 296 games, mean reward 17.670, eps 0.02, speed 109.29 f/s
# 617724: done 297 games, mean reward 17.700, eps 0.02, speed 111.43 f/s
# 619431: done 298 games, mean reward 17.710, eps 0.02, speed 107.20 f/s
# 621358: done 299 games, mean reward 17.670, eps 0.02, speed 108.75 f/s
# 623282: done 300 games, mean reward 17.760, eps 0.02, speed 109.11 f/s
# Best mean reward updated 17.720 -> 17.760, model saved
# 625058: done 301 games, mean reward 17.740, eps 0.02, speed 108.27 f/s
# 626688: done 302 games, mean reward 17.770, eps 0.02, speed 109.59 f/s
# Best mean reward updated 17.760 -> 17.770, model saved
# 628370: done 303 games, mean reward 17.760, eps 0.02, speed 109.24 f/s
# 630002: done 304 games, mean reward 17.800, eps 0.02, speed 110.80 f/s
# Best mean reward updated 17.770 -> 17.800, model saved
# 632158: done 305 games, mean reward 17.770, eps 0.02, speed 107.37 f/s
# 634016: done 306 games, mean reward 17.800, eps 0.02, speed 108.26 f/s
# 635774: done 307 games, mean reward 17.800, eps 0.02, speed 108.22 f/s
# 637650: done 308 games, mean reward 17.780, eps 0.02, speed 106.25 f/s
# 639555: done 309 games, mean reward 17.770, eps 0.02, speed 107.35 f/s
# 641403: done 310 games, mean reward 17.740, eps 0.02, speed 109.06 f/s
# 643283: done 311 games, mean reward 17.730, eps 0.02, speed 109.42 f/s
# 644914: done 312 games, mean reward 17.750, eps 0.02, speed 108.70 f/s
# 646640: done 313 games, mean reward 17.840, eps 0.02, speed 108.44 f/s
# Best mean reward updated 17.800 -> 17.840, model saved
# 648620: done 314 games, mean reward 17.840, eps 0.02, speed 109.42 f/s
# 650799: done 315 games, mean reward 17.770, eps 0.02, speed 108.63 f/s
# 652432: done 316 games, mean reward 17.770, eps 0.02, speed 108.69 f/s
# 654066: done 317 games, mean reward 17.780, eps 0.02, speed 108.96 f/s
# 655790: done 318 games, mean reward 17.770, eps 0.02, speed 110.83 f/s
# 657420: done 319 games, mean reward 17.800, eps 0.02, speed 109.14 f/s
# 659371: done 320 games, mean reward 17.770, eps 0.02, speed 108.91 f/s
# 661001: done 321 games, mean reward 17.880, eps 0.02, speed 109.26 f/s
# Best mean reward updated 17.840 -> 17.880, model saved
# 662857: done 322 games, mean reward 17.880, eps 0.02, speed 110.48 f/s
# 664730: done 323 games, mean reward 17.940, eps 0.02, speed 108.65 f/s
# Best mean reward updated 17.880 -> 17.940, model saved
# 666360: done 324 games, mean reward 17.990, eps 0.02, speed 108.67 f/s
# Best mean reward updated 17.940 -> 17.990, model saved
# 668698: done 325 games, mean reward 17.870, eps 0.02, speed 109.22 f/s
# 670486: done 326 games, mean reward 17.880, eps 0.02, speed 109.20 f/s
# 672321: done 327 games, mean reward 17.890, eps 0.02, speed 108.05 f/s
# 674043: done 328 games, mean reward 17.910, eps 0.02, speed 108.32 f/s
# 675755: done 329 games, mean reward 17.920, eps 0.02, speed 109.92 f/s
# 677632: done 330 games, mean reward 17.930, eps 0.02, speed 108.05 f/s
# 679258: done 331 games, mean reward 17.980, eps 0.02, speed 107.56 f/s
# 681061: done 332 games, mean reward 18.020, eps 0.02, speed 108.87 f/s
# Best mean reward updated 17.990 -> 18.020, model saved
# 683420: done 333 games, mean reward 17.900, eps 0.02, speed 108.52 f/s
# 685145: done 334 games, mean reward 17.920, eps 0.02, speed 108.21 f/s
# 686776: done 335 games, mean reward 17.930, eps 0.02, speed 108.76 f/s
# 688709: done 336 games, mean reward 17.890, eps 0.02, speed 109.50 f/s
# 690519: done 337 games, mean reward 17.870, eps 0.02, speed 108.67 f/s
# 692150: done 338 games, mean reward 17.910, eps 0.02, speed 109.74 f/s
# 694715: done 339 games, mean reward 17.770, eps 0.02, speed 109.36 f/s
# 696487: done 340 games, mean reward 17.740, eps 0.02, speed 108.23 f/s
# 698411: done 341 games, mean reward 17.690, eps 0.02, speed 108.78 f/s
# 700335: done 342 games, mean reward 17.660, eps 0.02, speed 109.05 f/s
# 702191: done 343 games, mean reward 17.700, eps 0.02, speed 110.11 f/s
# 704068: done 344 games, mean reward 17.690, eps 0.02, speed 108.05 f/s
# 705698: done 345 games, mean reward 17.710, eps 0.02, speed 109.26 f/s
# 707542: done 346 games, mean reward 17.730, eps 0.02, speed 109.27 f/s
# 709359: done 347 games, mean reward 17.730, eps 0.02, speed 109.92 f/s
# 711341: done 348 games, mean reward 17.710, eps 0.02, speed 108.23 f/s
# 713035: done 349 games, mean reward 17.740, eps 0.02, speed 108.23 f/s
# 714940: done 350 games, mean reward 17.730, eps 0.02, speed 110.51 f/s
# 716570: done 351 games, mean reward 17.740, eps 0.02, speed 109.25 f/s
# 718296: done 352 games, mean reward 17.760, eps 0.02, speed 108.53 f/s
# 720271: done 353 games, mean reward 17.760, eps 0.02, speed 110.02 f/s
# 722042: done 354 games, mean reward 17.830, eps 0.02, speed 110.32 f/s
# 723925: done 355 games, mean reward 17.810, eps 0.02, speed 107.64 f/s
# 725963: done 356 games, mean reward 17.790, eps 0.02, speed 108.49 f/s
# 727804: done 357 games, mean reward 17.780, eps 0.02, speed 106.78 f/s
# 729861: done 358 games, mean reward 17.750, eps 0.02, speed 106.07 f/s
# 731492: done 359 games, mean reward 17.780, eps 0.02, speed 109.30 f/s
# 733758: done 360 games, mean reward 17.780, eps 0.02, speed 109.49 f/s
# 735388: done 361 games, mean reward 17.780, eps 0.02, speed 109.28 f/s
# 737342: done 362 games, mean reward 17.770, eps 0.02, speed 107.18 f/s
# 739467: done 363 games, mean reward 17.720, eps 0.02, speed 105.89 f/s
# 741244: done 364 games, mean reward 17.720, eps 0.02, speed 107.20 f/s
# 742875: done 365 games, mean reward 17.750, eps 0.02, speed 105.83 f/s
# 744714: done 366 games, mean reward 17.730, eps 0.02, speed 105.87 f/s
# 746585: done 367 games, mean reward 17.740, eps 0.02, speed 106.35 f/s
# 748310: done 368 games, mean reward 17.780, eps 0.02, speed 104.84 f/s
# 750276: done 369 games, mean reward 17.770, eps 0.02, speed 103.47 f/s
# 752149: done 370 games, mean reward 17.780, eps 0.02, speed 109.38 f/s
# 753876: done 371 games, mean reward 17.810, eps 0.02, speed 109.98 f/s
# 755619: done 372 games, mean reward 17.820, eps 0.02, speed 108.18 f/s
# 757249: done 373 games, mean reward 17.840, eps 0.02, speed 108.11 f/s
# 759209: done 374 games, mean reward 17.780, eps 0.02, speed 110.12 f/s
# 761147: done 375 games, mean reward 17.770, eps 0.02, speed 110.15 f/s
# 762832: done 376 games, mean reward 17.770, eps 0.02, speed 107.46 f/s
# 764688: done 377 games, mean reward 17.760, eps 0.02, speed 108.40 f/s
# 766321: done 378 games, mean reward 17.770, eps 0.02, speed 110.57 f/s
# 768076: done 379 games, mean reward 17.880, eps 0.02, speed 107.51 f/s
# 769981: done 380 games, mean reward 17.900, eps 0.02, speed 109.37 f/s
# 771825: done 381 games, mean reward 17.910, eps 0.02, speed 109.11 f/s
# 773910: done 382 games, mean reward 17.880, eps 0.02, speed 110.59 f/s
# 775664: done 383 games, mean reward 17.950, eps 0.02, speed 107.99 f/s
# 777363: done 384 games, mean reward 17.980, eps 0.02, speed 108.23 f/s
# 778995: done 385 games, mean reward 17.990, eps 0.02, speed 109.05 f/s
# 780721: done 386 games, mean reward 18.040, eps 0.02, speed 110.46 f/s
# Best mean reward updated 18.020 -> 18.040, model saved
# 782722: done 387 games, mean reward 18.330, eps 0.02, speed 107.84 f/s
# Best mean reward updated 18.040 -> 18.330, model saved
# 784352: done 388 games, mean reward 18.370, eps 0.02, speed 108.82 f/s
# Best mean reward updated 18.330 -> 18.370, model saved
# 786368: done 389 games, mean reward 18.400, eps 0.02, speed 108.91 f/s
# Best mean reward updated 18.370 -> 18.400, model saved
# 788202: done 390 games, mean reward 18.410, eps 0.02, speed 108.45 f/s
# Best mean reward updated 18.400 -> 18.410, model saved
# 790035: done 391 games, mean reward 18.410, eps 0.02, speed 108.46 f/s
# 791730: done 392 games, mean reward 18.430, eps 0.02, speed 108.37 f/s
# Best mean reward updated 18.410 -> 18.430, model saved
# 793780: done 393 games, mean reward 18.330, eps 0.02, speed 109.11 f/s
# 795719: done 394 games, mean reward 18.310, eps 0.02, speed 106.46 f/s
# 797897: done 395 games, mean reward 18.290, eps 0.02, speed 106.99 f/s
# 799775: done 396 games, mean reward 18.270, eps 0.02, speed 108.81 f/s
# 801684: done 397 games, mean reward 18.260, eps 0.02, speed 106.85 f/s
# 803369: done 398 games, mean reward 18.260, eps 0.02, speed 108.84 f/s
# 805054: done 399 games, mean reward 18.300, eps 0.02, speed 108.68 f/s
# 806782: done 400 games, mean reward 18.300, eps 0.02, speed 108.26 f/s
# 808644: done 401 games, mean reward 18.300, eps 0.02, speed 108.04 f/s
# 810526: done 402 games, mean reward 18.290, eps 0.02, speed 107.86 f/s
# 812327: done 403 games, mean reward 18.290, eps 0.02, speed 106.83 f/s
# 814092: done 404 games, mean reward 18.270, eps 0.02, speed 105.76 f/s
# 815865: done 405 games, mean reward 18.300, eps 0.02, speed 104.78 f/s
# 817551: done 406 games, mean reward 18.330, eps 0.02, speed 105.18 f/s
# 819182: done 407 games, mean reward 18.350, eps 0.02, speed 106.43 f/s
# 820831: done 408 games, mean reward 18.380, eps 0.02, speed 104.77 f/s
# 822542: done 409 games, mean reward 18.390, eps 0.02, speed 106.39 f/s
# 824282: done 410 games, mean reward 18.410, eps 0.02, speed 104.91 f/s
# 825930: done 411 games, mean reward 18.440, eps 0.02, speed 106.00 f/s
# Best mean reward updated 18.430 -> 18.440, model saved
# 827710: done 412 games, mean reward 18.420, eps 0.02, speed 104.69 f/s
# 829340: done 413 games, mean reward 18.430, eps 0.02, speed 106.05 f/s
# 831462: done 414 games, mean reward 18.390, eps 0.02, speed 108.50 f/s
# 833092: done 415 games, mean reward 18.490, eps 0.02, speed 105.39 f/s
# Best mean reward updated 18.440 -> 18.490, model saved
# 834818: done 416 games, mean reward 18.480, eps 0.02, speed 106.49 f/s
# 836608: done 417 games, mean reward 18.460, eps 0.02, speed 106.15 f/s
# 838346: done 418 games, mean reward 18.450, eps 0.02, speed 108.16 f/s
# 840184: done 419 games, mean reward 18.410, eps 0.02, speed 106.90 f/s
# 841915: done 420 games, mean reward 18.430, eps 0.02, speed 109.45 f/s
# 843643: done 421 games, mean reward 18.420, eps 0.02, speed 109.88 f/s
# 845439: done 422 games, mean reward 18.430, eps 0.02, speed 107.99 f/s
# 847070: done 423 games, mean reward 18.460, eps 0.02, speed 107.62 f/s
# 848993: done 424 games, mean reward 18.420, eps 0.02, speed 108.53 f/s
# 850678: done 425 games, mean reward 18.530, eps 0.02, speed 109.72 f/s
# Best mean reward updated 18.490 -> 18.530, model saved
# 852584: done 426 games, mean reward 18.500, eps 0.02, speed 108.84 f/s
# 854215: done 427 games, mean reward 18.520, eps 0.02, speed 106.51 f/s
# 855933: done 428 games, mean reward 18.510, eps 0.02, speed 108.18 f/s
# 857563: done 429 games, mean reward 18.530, eps 0.02, speed 107.14 f/s
# 859193: done 430 games, mean reward 18.550, eps 0.02, speed 107.23 f/s
# Best mean reward updated 18.530 -> 18.550, model saved
# 861173: done 431 games, mean reward 18.520, eps 0.02, speed 108.54 f/s
# 863027: done 432 games, mean reward 18.520, eps 0.02, speed 108.89 f/s
# 864869: done 433 games, mean reward 18.660, eps 0.02, speed 107.53 f/s
# Best mean reward updated 18.550 -> 18.660, model saved
# 866499: done 434 games, mean reward 18.670, eps 0.02, speed 107.62 f/s
# Best mean reward updated 18.660 -> 18.670, model saved
# 868456: done 435 games, mean reward 18.620, eps 0.02, speed 108.25 f/s
# 870202: done 436 games, mean reward 18.650, eps 0.02, speed 109.89 f/s
# 871828: done 437 games, mean reward 18.680, eps 0.02, speed 107.74 f/s
# Best mean reward updated 18.670 -> 18.680, model saved
# 873459: done 438 games, mean reward 18.680, eps 0.02, speed 106.96 f/s
# 875090: done 439 games, mean reward 18.850, eps 0.02, speed 108.79 f/s
# Best mean reward updated 18.680 -> 18.850, model saved
# 876834: done 440 games, mean reward 18.870, eps 0.02, speed 110.23 f/s
# Best mean reward updated 18.850 -> 18.870, model saved
# 878464: done 441 games, mean reward 18.920, eps 0.02, speed 100.88 f/s
# Best mean reward updated 18.870 -> 18.920, model saved
# 880147: done 442 games, mean reward 18.960, eps 0.02, speed 107.69 f/s
# Best mean reward updated 18.920 -> 18.960, model saved
# 881777: done 443 games, mean reward 18.980, eps 0.02, speed 103.82 f/s
# Best mean reward updated 18.960 -> 18.980, model saved
# 883615: done 444 games, mean reward 18.990, eps 0.02, speed 108.45 f/s
# Best mean reward updated 18.980 -> 18.990, model saved
# 885280: done 445 games, mean reward 18.980, eps 0.02, speed 107.05 f/s
# 886940: done 446 games, mean reward 19.010, eps 0.02, speed 109.08 f/s
# Best mean reward updated 18.990 -> 19.010, model saved
# Solved in 886940 frames!

# %%
plt.figure(figsize=(20,5))
plt.plot(total_rewards)
plt.title('Total frames %s ' % (frame_idx))
plt.xlabel('Number of games')
plt.ylabel('Reward for game')
plt.show()

# %% [markdown]
# # Inference
#
# Для инференса восполозуюсь оберткой от gym wrappers **RecordVideo**, которая позволяет записывать видео игры. Так как я в процессе обучения агента загружала веса лучшей модели в виде словаря, то я могу воспользоваться ими для инференса.

# %%
from gymnasium.wrappers.record_video import RecordVideo
env = RecordVideo(env, "./play_recording")

# %% [markdown]
# Модель нужно загрузить в директорию ноутбука для того, чтобы сработал код. Веса модели можно скачать вот здесь https://github.com/shakhovak/Study-projects-in-Uni/blob/master/Reinforced_Learning_beginner/PongNoFrameskip-v4-best.dat

# %%
model_path = 'PongNoFrameskip-v4-best.dat'
inference_net = DQN(env.observation_space.shape, env.action_space.n)
inference_net.load_state_dict(torch.load(model_path, map_location=lambda storage, loc: storage))
# Out:
# <All keys matched successfully>

# %%
FPS = 25
state, info = env.reset()
state = np.expand_dims(state, 0)
total_reward = 0.0
c = collections.Counter()

while True:
    start_ts = time.time()
    #env.render()
    state_v = torch.tensor(np.concatenate([state]))
    q_vals = inference_net(state_v).cpu().data.numpy()[0]
    action = np.argmax(q_vals)
    c[action] += 1
    state, reward, done, _ , _ = env.step(action)
    state = np.expand_dims(state, 0)
    total_reward += reward
    if done:
        break
    delta = 1/FPS - (time.time() - start_ts)
    if delta > 0:
          time.sleep(delta)
print("Total reward: %.2f" % total_reward)
print("Action counts:", c)
env.env.close()
# Out:
# Moviepy - Building video /content/play_recording/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/play_recording/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/play_recording/rl-video-episode-0.mp4
# Total reward: 21.00
# Action counts: Counter({5: 788, 0: 268, 4: 215, 1: 155, 2: 110, 3: 94})

# %% [markdown]
# Функция для просмотра видео:

# %%
import glob
import io
import base64
from IPython import display as ipythondisplay
from IPython.display import HTML
import matplotlib.pyplot as plt
# %matplotlib inline

def show_video(folder="./play_recording"):
    mp4list = glob.glob(folder + '/*.mp4')
    if len(mp4list) > 0:
        mp4 = sorted(mp4list, key=lambda x: x[-15:], reverse=True)[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

# %%
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# # Выводы:
#
# Агент довольно быстро научился играть в pong и полученная модель дает требуемые средние результаты.
